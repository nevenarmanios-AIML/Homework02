# %%
mData = [
  { 
    "name": "thiago", 
    "points": 23, 
    "zip": 11233
  },
  { "name": "lex", "points": 45, "zip": 11011 },
  { "name": "neven", "points": 12, "zip": 11215 },
]

def someFunction(item):
  return item["points"]

sorted(mData, key=someFunction)
# Out:
# [{'name': 'neven', 'points': 12, 'zip': 11215}, {'name': 'thiago', 'points': 23, 'zip': 11233}, {'name': 'lex', 'points': 45, 'zip': 11011}]
