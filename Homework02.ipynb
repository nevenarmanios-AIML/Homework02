# %% [markdown]
# # Homework02
#
# Some exercises to get started with Python, lists, objects, dicts and datasets.
#
# ## Goals
#
# - Gain experience with a popular scripting language used for ML/AI projects and research
# - Get familiar with Python's notation for lists and objects
# - Experiment with Python's unique functionalities for processing lists and objects
# - Learn to load and process datasets using Python

# %% [markdown]
# ### Setup
#
# Run the following 2 cells to import all necessary libraries and helpers for Homework 02

# %%
# !wget -q https://github.com/PSAM-5020-2026S-A/5020-utils/raw/main/src/data_utils.py

# %%
import matplotlib.pyplot as plt

from Homework02_utils import Tests
from data_utils import object_from_json_url

# %% [markdown]
# ### Exercise 01:
#
# Finding the sum of integer sequences.
#
# Create a function ```sum_of_ints(i0, i1)``` that returns the sum of all integers between two integers.
#
# For example, ```sum_of_ints(4, 32)``` should return $522$.

# %%
## Work on exercise 01 here

def sum_of_ints(i0, i1):
    total = 0
    for i in range(i0, i1 + 1):
        total = total + i
    return total

a = 4
b = 32

print(sum_of_ints(a, b))
# Out:
# 522

# %% [markdown]
# ### Exercise 01 testing:
#
# Running the following cell will test the ```sum_of_ints()``` function on a small set of input pairs and report any combination that isn't computing correctly, if any.

# %%
# Test 01
Tests.test("01", sum_of_ints)
# Out:
# ERROR Check sum of sum_of_ints(-7, -88) should be -3895 not 0

# %% [markdown]
# ### Exercise 02:
#
# Working with lists and dictionaries/objects.
#
# Write a function `sum_objects(in_list)` that accept a list of objects and returns a sum according to the following specifications:
#
# Each object in the list has 2 fields, `type` and `amount`, and so will look something like this:
#
# ```python
# test_list = [
#   { "type": "cost", "amount": 10.00 },
#   { "type": "cost", "amount": 15.99 },
#   { "type": "income", "amount": 150.25 },
#   { "type": "income", "amount": 243.52 },
# ]
# ```
#
# The `sum_objects(in_list)` function should iterate through all of the items in `in_list` and sum their `amount`s using positive values when `type` is `"income"`, and negative values when `type` is `"cost"`.
#
# For example, passing the above list to the function should return $367.78$.

# %%
# Implement 02 here

def sum_objects(in_list):
  # TODO: fill this in
  sum = 0
  for item in in_list: 
    if item["type"] == "cost":
      sum = sum - item["amount"]
    else:
      sum = sum + item["amount"]
  return sum

# %%
# Run this cell to test if function returns 367.78

test_list = [
  { "type": "cost", "amount": 10.00 },
  { "type": "cost", "amount": 15.99 },
  { "type": "income", "amount": 150.25 },
  { "type": "income", "amount": 243.52 },
]

sum_objects(test_list)
# Out:
# 367.78

# %% [markdown]
# #### Exercise 02 test:
#
# Run the following cell to test the `sum_objects()` function.

# %%
# Test 02
Tests.test("02", sum_objects)
# Out:
# 02: All tests passed 🎉🎉🎉

# %% [markdown]
# ### Exercise 03:
#
# Working with data files.
#
# Find the name and population of the 3 cities that are geographically closest to the world's most populous city.
#
# # 🤔😱

# %% [markdown]
# #### Load Data:
#
# Let's break this down into a few sub-problems.
#
# First, let's load a JSON file that has information about large cities in the world.
#
# The file at this [URL](https://raw.githubusercontent.com/PSAM-5020-2025S-A/5020-utils/main/datasets/json/cities50k.json) has a list of cities formatted like this:
#
# ```py
# {
#   "name": "Pittsburgh",
#   "country": "US",
#   "admin1": "Pennsylvania",
#   "lat": 40.4406200,
#   "lon": -79.9958900,
#   "pop": 304391
# }
# ```
#
# This is just like how we loaded ANSUR data files in class:

# %%
# Define the location of the json file here
CITIES_FILE = "https://raw.githubusercontent.com/PSAM-5020-2026S-A/5020-utils/main/datasets/json/cities50k.json"

# Use the object_from_json_url() function to load contents from 
# the json file into a Python object called "info_cities"

info_cities = object_from_json_url(CITIES_FILE)

# %% [markdown]
# #### Exercise 03A:
#
# Ok. We should now have a list of objects with information about cities.
#
# Explore the data and answer the following questions:
# - How many cities are in this list?
# - What's the name of the first city on the list?
# - What are the latitude and longitude of the last city on the list?
# - What are the populations for the largest and smallest cities?
# - What's the name of the city with the largest population?

# %%
# Work on 03A here

# How many cities are in the list?

num_cities = len(info_cities)


# What's the name of the first city on the list?

first_city = info_cities[0]["name"]


# What are the latitude and longitude of the last city on the list?

last_latitude = info_cities[-1]["lat"]
last_longitude = info_cities[-1]["lon"]


# What are the populations for the largest and smallest cities?

sorted_data = sorted(info_cities, key=lambda x: x["pop"])

largest_population = sorted_data[-1]["pop"]

smallest_population = sorted_data[0]["pop"]


# What's the name of the city with the largest population?

largest_city_name = sorted_data[-1]["name"]

# %% [markdown]
# #### Test 03A

# %%
# Test 03A
answers = [num_cities, first_city, last_latitude, last_longitude, largest_population, smallest_population, largest_city_name]

Tests.test("03A", answers)
# Out:
# 03A: All tests passed 🎉🎉🎉

# %% [markdown]
# #### Exercise 03B:
#
# We have the largest city's name and population, but we need its position.
#
# We can recycle some of the logic from above to get the whole object that contains information for the largest city.

# %%
# Work on 03B here

largest_city = sorted_data[-1]

print (largest_city)
# Out:
# {'name': 'Shanghai', 'country': 'CN', 'admin1': 'Shanghai Shi', 'lat': 31.22222, 'lon': 121.45806, 'pop': 22315474}

# %%
# Test 03B
Tests.test("03B", largest_city)
# Out:
# 03B: All tests passed 🎉🎉🎉

# %% [markdown]
# #### Exercise 03C:
#
# We should have all info about the largest city here.
#
# Now, we'll iterate through the list and use each city's latitude and longitude to calculate its distance from the largest city.
#
# Althought not $100\%$ correct, it's ok to use the [2D Euclidean distances](https://en.wikipedia.org/wiki/Euclidean_distance#Two_dimensions) for this.
#
# Could be useful to define a function `distance(cityA, cityB)` that returns the distance between two cities.

# %%
# Work on 03C here

# Implement the helper function for calculating distances between 2 cities

import math


def distance(cityA, cityB):
  # find the lat of two cities and subtract the values to find the difference 
  lat_dif = cityA["lat"] - cityB["lat"]
  # square that difference
  lat_square = lat_dif * lat_dif
  # find the lon of the same two cities and subtract the values to find that difference 
  lon_dif = cityA["lon"] - cityB["lon"]
  # square that difference
  lon_square = lon_dif * lon_dif
  # add the two differnce values
  #find the square root
  #return the value
  return math.sqrt(lat_square + lon_square)

# %%
# Test 03C
Tests.test("03C", distance)
# Out:
# 03C: All tests passed 🎉🎉🎉

# %% [markdown]
# #### Exercise 03D:
#
# Ok. We implemented a function to calculate the distance between 2 cities, let's use it now.
#
# Iterate through the list of cities again, calculate the distance from each city to the largest city, and add that as a new feature/key to each city's entry:
#
# ```py
# {
#   "name": "Pittsburgh",
#   "country": "US",
#   "admin1": "Pennsylvania",
#   "lat": 40.4406200,
#   "lon": -79.9958900,
#   "pop": 304391,
#   "distance": 1222.32
# }
# ```
#
# Just make sure the key that holds the distance value is called `distance`.

# %%
# Work on 03D here

# Now calculate every city's distance from the largest city and

# find the largest city
largest_city = sorted_data[-1]
print (largest_city)

# find the lat and lon of the largest city - 
print (largest_city["lat"])

#compare largest city with all other cities
import math


# def distance(cityA, cityB):
#   # find the lat of two cities and subtract the values to find the difference 
#   lat_dif = cityA["lat"] - cityB["lat"]
#   # square that difference
#   lat_square = lat_dif * lat_dif
#   # find the lon of the same two cities and subtract the values to find that difference 
#   lon_dif = cityA["lon"] - cityB["lon"]
#   # square that difference
#   lon_square = lon_dif * lon_dif
#   # add the two differnce values
#   #find the square root
#   #return the value
#   return math.sqrt(lat_square + lon_square) 

# add that info to each city's entry

for city in info_cities:
  # print(distance(largest_city, city))
  city["distance"] = distance(largest_city, city)
  print(city)
# Out:
# {'name': 'Shanghai', 'country': 'CN', 'admin1': 'Shanghai Shi', 'lat': 31.22222, 'lon': 121.45806, 'pop': 22315474, 'distance': 0.0}
# 31.22222
# {'name': 'Abu Dhabi', 'country': 'AE', 'admin1': 'Abū Z̧aby', 'lat': 24.45118, 'lon': 54.39696, 'pop': 603492, 'distance': 67.40206314269321}
# {'name': 'Ajman City', 'country': 'AE', 'admin1': '‘Ajmān', 'lat': 25.40177, 'lon': 55.47878, 'pop': 490035, 'distance': 66.235511831048}
# {'name': 'Al Ain City', 'country': 'AE', 'admin1': 'Abū Z̧aby', 'lat': 24.19167, 'lon': 55.76056, 'pop': 55091, 'distance': 66.0726126284749}
# {'name': 'Al Fujairah City', 'country': 'AE', 'admin1': 'Al Fujayrah', 'lat': 25.11641, 'lon': 56.34141, 'pop': 86512, 'distance': 65.40228606844411}
# {'name': 'Al Shamkhah City', 'country': 'AE', 'admin1': 'Abū Z̧aby', 'lat': 24.39268, 'lon': 54.70779, 'pop': 61710, 'distance': 67.09874187855165}
# {'name': 'Bani Yas City', 'country': 'AE', 'admin1': 'Abū Z̧aby', 'lat': 24.30978, 'lon': 54.62944, 'pop': 80498, 'distance': 67.18516412019845}
# {'name': 'Dubai', 'country': 'AE', 'admin1': 'Dubai', 'lat': 25.07725, 'lon': 55.30927, 'pop': 2956587, 'distance': 66.43359899000656}
# {'name': 'Khalifah A City', 'country': 'AE', 'admin1': 'Abū Z̧aby', 'lat': 24.42588, 'lon': 54.605, 'pop': 85374, 'distance': 67.19763291038755}
# {'name': 'Musaffah', 'country': 'AE', 'admin1': 'Abū Z̧aby', 'lat': 24.35893, 'lon': 54.48267, 'pop': 243341, 'distance': 67.32612877090291}
# {'name': 'Ras Al Khaimah City', 'country': 'AE', 'admin1': 'Ra’s al Khaymah', 'lat': 25.78953, 'lon': 55.9432, 'pop': 351943, 'distance': 65.73972164114859}
# {'name': 'Reef Al Fujairah City', 'country': 'AE', 'admin1': 'Al Fujayrah', 'lat': 25.14479, 'lon': 56.24764, 'pop': 82310, 'distance': 65.49300750447561}
# {'name': 'Sharjah', 'country': 'AE', 'admin1': 'Ash Shāriqah', 'lat': 25.33737, 'lon': 55.41206, 'pop': 1324473, 'distance': 66.30765849826474}
# {'name': 'Umm Al Quwain City', 'country': 'AE', 'admin1': 'Umm al Qaywayn', 'lat': 25.56473, 'lon': 55.55517, 'pop': 62747, 'distance': 66.14528028100118}
# {'name': 'Zayed City', 'country': 'AE', 'admin1': 'Abū Z̧aby', 'lat': 23.65416, 'lon': 53.70522, 'pop': 63482, 'distance': 68.17420964139738}
# {'name': 'Baghlān', 'country': 'AF', 'admin1': 'Wilāyat-e Baghlān', 'lat': 36.13068, 'lon': 68.70829, 'pop': 108449, 'distance': 52.97764825494333}
# {'name': 'Balkh', 'country': 'AF', 'admin1': 'Balkh', 'lat': 36.75635, 'lon': 66.8972, 'pop': 114883, 'distance': 54.840806328832365}
# {'name': 'Bāmyān', 'country': 'AF', 'admin1': 'Wilāyat-e Bāmyān', 'lat': 34.82156, 'lon': 67.82734, 'pop': 61863, 'distance': 53.751366272439995}
# {'name': 'Bāzārak', 'country': 'AF', 'admin1': 'Panjshir', 'lat': 35.31292, 'lon': 69.51519, 'pop': 65000, 'distance': 52.10370015965181}
# {'name': 'Charikar', 'country': 'AF', 'admin1': 'Parwān', 'lat': 35.01361, 'lon': 69.17139, 'pop': 53676, 'distance': 52.423949658729455}
# {'name': 'Gardez', 'country': 'AF', 'admin1': 'Wilāyat-e Paktiyā', 'lat': 33.59744, 'lon': 69.22592, 'pop': 103601, 'distance': 52.28611784238719}
# {'name': 'Ghazni', 'country': 'AF', 'admin1': 'Wilāyat-e Ghaznī', 'lat': 33.55391, 'lon': 68.42096, 'pop': 141000, 'distance': 53.08832974078296}
# {'name': 'Herāt', 'country': 'AF', 'admin1': 'Herāt', 'lat': 34.34817, 'lon': 62.19967, 'pop': 272806, 'distance': 59.340781498010294}
# {'name': 'Jalālābād', 'country': 'AF', 'admin1': 'Nangarhār', 'lat': 34.42647, 'lon': 70.45153, 'pop': 200331, 'distance': 51.10707701193055}
# {'name': 'Kabul', 'country': 'AF', 'admin1': 'Wilāyat-e Kābul', 'lat': 34.52813, 'lon': 69.17233, 'pop': 3043532, 'distance': 52.39013840944686}
# {'name': 'Kandahār', 'country': 'AF', 'admin1': 'Kandahār', 'lat': 31.61332, 'lon': 65.71013, 'pop': 391190, 'distance': 55.749301865538186}
# {'name': 'Khanabad', 'country': 'AF', 'admin1': 'Kunduz', 'lat': 36.6825, 'lon': 69.11556, 'pop': 71531, 'distance': 52.626532889108326}
# {'name': 'Khōst', 'country': 'AF', 'admin1': 'Velāyat-e Khowst', 'lat': 33.33951, 'lon': 69.92041, 'pop': 96123, 'distance': 51.58112333467157}
# {'name': 'Khulm', 'country': 'AF', 'admin1': 'Balkh', 'lat': 36.69736, 'lon': 67.69826, 'pop': 64933, 'distance': 54.03788720943483}
# {'name': 'Kunduz', 'country': 'AF', 'admin1': 'Kunduz', 'lat': 36.72895, 'lon': 68.857, 'pop': 161902, 'distance': 52.888520384072955}
# {'name': 'Maymana', 'country': 'AF', 'admin1': 'Faryab Province', 'lat': 35.92139, 'lon': 64.78361, 'pop': 75900, 'distance': 56.86893248067349}
# {'name': 'Mazār-e Sharīf', 'country': 'AF', 'admin1': 'Balkh', 'lat': 36.70904, 'lon': 67.11087, 'pop': 303282, 'distance': 54.62345883051072}
# {'name': 'Pul-e Khumrī', 'country': 'AF', 'admin1': 'Wilāyat-e Baghlān', 'lat': 35.94458, 'lon': 68.71512, 'pop': 56369, 'distance': 52.9539271802687}
# {'name': 'Sar-e Pul', 'country': 'AF', 'admin1': 'Sar-e Pul', 'lat': 36.21544, 'lon': 65.93249, 'pop': 52121, 'distance': 55.749629324268156}
# {'name': 'Shibirghān', 'country': 'AF', 'admin1': 'Wilāyat-e Jowzjān', 'lat': 36.66757, 'lon': 65.7529, 'pop': 55641, 'distance': 55.97067703046034}
# {'name': 'Taloqan', 'country': 'AF', 'admin1': 'Wilāyat-e Takhār', 'lat': 36.73605, 'lon': 69.53451, 'pop': 64256, 'distance': 52.215489712071076}
# {'name': 'Durrës', 'country': 'AL', 'admin1': 'Qarku i Durrësit', 'lat': 41.32355, 'lon': 19.45469, 'pop': 122034, 'distance': 102.50231392083694}
# {'name': 'Elbasan', 'country': 'AL', 'admin1': 'Qarku i Elbasanit', 'lat': 41.1125, 'lon': 20.08222, 'pop': 100903, 'distance': 101.85714787968492}
# {'name': 'Fier', 'country': 'AL', 'admin1': 'Qarku i Fierit', 'lat': 40.72389, 'lon': 19.55611, 'pop': 56297, 'distance': 102.34397464722288}
# {'name': 'Korçë', 'country': 'AL', 'admin1': 'Qarku i Korçës', 'lat': 40.61861, 'lon': 20.78083, 'pop': 58259, 'distance': 101.11477036271704}
# {'name': 'Patos', 'country': 'AL', 'admin1': 'Qarku i Fierit', 'lat': 40.68333, 'lon': 19.61944, 'pop': 60000, 'distance': 102.27715837828357}
# {'name': 'Pogradec', 'country': 'AL', 'admin1': 'Qarku i Korçës', 'lat': 40.9025, 'lon': 20.6525, 'pop': 61530, 'distance': 101.26928827533054}
# {'name': 'Shkodër', 'country': 'AL', 'admin1': 'Qarku i Shkodrës', 'lat': 42.06828, 'lon': 19.51258, 'pop': 88245, 'distance': 102.52081695906448}
# {'name': 'Tirana', 'country': 'AL', 'admin1': 'Qarku i Tiranës', 'lat': 41.3275, 'lon': 19.81889, 'pop': 374801, 'distance': 102.14028373843153}
# {'name': 'Vlorë', 'country': 'AL', 'admin1': 'Qarku i Vlorës', 'lat': 40.4686, 'lon': 19.48318, 'pop': 89546, 'distance': 102.3932209382965}
# {'name': 'Gyumri', 'country': 'AM', 'admin1': 'Shiraki Marz', 'lat': 40.7942, 'lon': 43.84528, 'pop': 148381, 'distance': 78.20080831071249}
# {'name': 'Vanadzor', 'country': 'AM', 'admin1': 'Lorru Marz', 'lat': 40.80456, 'lon': 44.4939, 'pop': 101098, 'distance': 77.55838551943434}
# {'name': 'Yerevan', 'country': 'AM', 'admin1': 'Yerevan', 'lat': 40.18111, 'lon': 44.51361, 'pop': 1093485, 'distance': 77.46425043744115}
# {'name': 'Benguela', 'country': 'AO', 'admin1': 'Benguela', 'lat': -12.57626, 'lon': 13.40547, 'pop': 151226, 'distance': 116.59189103886472}
# {'name': 'Cabinda', 'country': 'AO', 'admin1': 'Cabinda', 'lat': -5.55, 'lon': 12.2, 'pop': 66020, 'distance': 115.280179730481}
# {'name': 'Cuito', 'country': 'AO', 'admin1': 'Província do Bié', 'lat': -12.38333, 'lon': 16.93333, 'pop': 113624, 'distance': 113.25574233731109}
# {'name': 'Huambo', 'country': 'AO', 'admin1': 'Huambo', 'lat': -12.77611, 'lon': 15.73917, 'pop': 226145, 'distance': 114.50911206371744}
# {'name': 'Lobito', 'country': 'AO', 'admin1': 'Benguela', 'lat': -12.3644, 'lon': 13.53601, 'pop': 207932, 'distance': 116.3914185806965}
# {'name': 'Luanda', 'country': 'AO', 'admin1': 'Luanda Province', 'lat': -8.83682, 'lon': 13.23432, 'pop': 2776168, 'distance': 115.39975990143654}
# {'name': 'Lubango', 'country': 'AO', 'admin1': 'Huila Province', 'lat': -14.91717, 'lon': 13.4925, 'pop': 102541, 'distance': 117.41126630645672}
# {'name': 'Malanje', 'country': 'AO', 'admin1': 'Malanje Province', 'lat': -9.54015, 'lon': 16.34096, 'pop': 87046, 'distance': 112.74384914675791}
# {'name': 'N’dalatando', 'country': 'AO', 'admin1': 'Cuanza Norte Province', 'lat': -9.29782, 'lon': 14.91162, 'pop': 383100, 'distance': 113.99130457309101}
# {'name': 'Namibe', 'country': 'AO', 'admin1': 'Namibe Province', 'lat': -15.19611, 'lon': 12.15222, 'pop': 80149, 'distance': 118.75364423079613}
# {'name': 'Soio', 'country': 'AO', 'admin1': 'Zaire', 'lat': -6.1349, 'lon': 12.36894, 'pop': 67491, 'distance': 115.30824132328443}
# {'name': 'Uíge', 'country': 'AO', 'admin1': 'Província do Uíge', 'lat': -7.60874, 'lon': 15.06131, 'pop': 60008, 'distance': 113.26125491572174}
# {'name': 'Azul', 'country': 'AR', 'admin1': 'Buenos Aires', 'lat': -36.77698, 'lon': -59.85854, 'pop': 53941, 'distance': 193.6481361547278}
# {'name': 'Bahía Blanca', 'country': 'AR', 'admin1': 'Buenos Aires', 'lat': -38.71959, 'lon': -62.27243, 'pop': 276546, 'distance': 196.59285272287036}
# {'name': 'Barranqueras', 'country': 'AR', 'admin1': 'Chaco Province', 'lat': -27.48132, 'lon': -58.93925, 'pop': 50823, 'distance': 189.7084475287479}
# {'name': 'Berazategui', 'country': 'AR', 'admin1': 'Buenos Aires', 'lat': -34.76531, 'lon': -58.21278, 'pop': 167498, 'distance': 191.4052372893869}
# {'name': 'Buenos Aires', 'country': 'AR', 'admin1': 'Ciudad Autónoma de Buenos Aires', 'lat': -34.61315, 'lon': -58.37723, 'pop': 13076300, 'distance': 191.50725174891159}
# {'name': 'Campana', 'country': 'AR', 'admin1': 'Buenos Aires', 'lat': -34.16327, 'lon': -58.95919, 'pop': 81612, 'distance': 191.90009484130695}
# {'name': 'Chimbas', 'country': 'AR', 'admin1': 'San Juan Province', 'lat': -31.48333, 'lon': -68.53333, 'pop': 73829, 'distance': 200.07177280899626}
# {'name': 'Chivilcoy', 'country': 'AR', 'admin1': 'Buenos Aires', 'lat': -34.89566, 'lon': -60.01667, 'pop': 54514, 'distance': 193.14412153691683}
# {'name': 'Cipolletti', 'country': 'AR', 'admin1': 'Río Negro Province', 'lat': -38.93392, 'lon': -67.99032, 'pop': 75078, 'distance': 202.0212183517464}
# {'name': 'Comodoro Rivadavia', 'country': 'AR', 'admin1': 'Chubut Province', 'lat': -45.86413, 'lon': -67.49656, 'pop': 140850, 'distance': 204.07389293015143}
# {'name': 'Concepción del Uruguay', 'country': 'AR', 'admin1': 'Entre Ríos Province', 'lat': -32.48463, 'lon': -58.23217, 'pop': 67895, 'distance': 190.64926303129369}
# {'name': 'Concordia', 'country': 'AR', 'admin1': 'Entre Ríos Province', 'lat': -31.39296, 'lon': -58.02089, 'pop': 145210, 'distance': 190.0877541019802}
# {'name': 'Córdoba', 'country': 'AR', 'admin1': 'Córdoba Province', 'lat': -31.4135, 'lon': -64.18105, 'pop': 1428214, 'distance': 195.92118972053663}
# {'name': 'Corrientes', 'country': 'AR', 'admin1': 'Corrientes Province', 'lat': -27.46784, 'lon': -58.8344, 'pop': 339067, 'distance': 189.6045734565894}
# {'name': 'Don Torcuato', 'country': 'AR', 'admin1': 'Buenos Aires', 'lat': -34.49459, 'lon': -58.62729, 'pop': 64867, 'distance': 191.70141470839124}
# {'name': 'Formosa', 'country': 'AR', 'admin1': 'Formosa Province', 'lat': -26.18489, 'lon': -58.17313, 'pop': 221383, 'distance': 188.58139011940762}
# {'name': 'General Pico', 'country': 'AR', 'admin1': 'La Pampa Province', 'lat': -35.65662, 'lon': -63.75682, 'pop': 57029, 'distance': 196.91960545654157}
# {'name': 'General Roca', 'country': 'AR', 'admin1': 'Río Negro Province', 'lat': -39.03333, 'lon': -67.58333, 'pop': 73212, 'distance': 201.6742160984755}
# {'name': 'Gobernador Gálvez', 'country': 'AR', 'admin1': 'Santa Fe Province', 'lat': -33.03016, 'lon': -60.64045, 'pop': 74650, 'distance': 193.10162008612073}
# {'name': 'Goya', 'country': 'AR', 'admin1': 'Corrientes Province', 'lat': -29.13995, 'lon': -59.26343, 'pop': 70245, 'distance': 190.53568829730824}
# {'name': 'Gualeguaychú', 'country': 'AR', 'admin1': 'Entre Ríos Province', 'lat': -33.00937, 'lon': -58.51722, 'pop': 78676, 'distance': 191.09369054211732}
# {'name': 'Hurlingham', 'country': 'AR', 'admin1': 'Buenos Aires', 'lat': -34.5904, 'lon': -58.62904, 'pop': 60000, 'distance': 191.73592396229353}
# {'name': 'José C. Paz', 'country': 'AR', 'admin1': 'Buenos Aires', 'lat': -34.51541, 'lon': -58.76813, 'pop': 230208, 'distance': 191.84085998538737}
# {'name': 'Junín', 'country': 'AR', 'admin1': 'Buenos Aires', 'lat': -34.58382, 'lon': -60.94332, 'pop': 85007, 'distance': 193.90899495997084}
# {'name': 'La Plata', 'country': 'AR', 'admin1': 'Buenos Aires', 'lat': -34.92145, 'lon': -57.95453, 'pop': 694167, 'distance': 191.21679458556196}
# {'name': 'La Rioja', 'country': 'AR', 'admin1': 'La Rioja Province', 'lat': -29.41105, 'lon': -66.85067, 'pop': 162620, 'distance': 197.82965203706394}
# {'name': 'Los Polvorines', 'country': 'AR', 'admin1': 'Buenos Aires', 'lat': -34.50316, 'lon': -58.70596, 'pop': 53354, 'distance': 191.7782565326549}
# {'name': 'Luján', 'country': 'AR', 'admin1': 'Buenos Aires', 'lat': -34.57028, 'lon': -59.105, 'pop': 81749, 'distance': 192.17614756471107}
# {'name': 'Mar del Plata', 'country': 'AR', 'admin1': 'Buenos Aires', 'lat': -38.00042, 'lon': -57.5562, 'pop': 553935, 'distance': 191.9319649561198}
# {'name': 'Mendoza', 'country': 'AR', 'admin1': 'Mendoza Province', 'lat': -32.89084, 'lon': -68.82717, 'pop': 876884, 'distance': 200.79579980347324}
# {'name': 'Mercedes', 'country': 'AR', 'admin1': 'Buenos Aires', 'lat': -34.65145, 'lon': -59.43068, 'pop': 52949, 'distance': 192.5099391149883}
# {'name': 'Merlo', 'country': 'AR', 'admin1': 'Buenos Aires', 'lat': -34.66627, 'lon': -58.72927, 'pop': 244168, 'distance': 191.85611016334352}
# {'name': 'Morón', 'country': 'AR', 'admin1': 'Buenos Aires', 'lat': -34.6509, 'lon': -58.61956, 'pop': 319934, 'distance': 191.74779571979124}
# {'name': 'Necochea', 'country': 'AR', 'admin1': 'Buenos Aires', 'lat': -38.5545, 'lon': -58.73961, 'pop': 80478, 'distance': 193.23558400922772}
# {'name': 'Neuquén', 'country': 'AR', 'admin1': 'Neuquén Province', 'lat': -38.95161, 'lon': -68.0591, 'pop': 242092, 'distance': 202.09186117044518}
# {'name': 'Oberá', 'country': 'AR', 'admin1': 'Misiones Province', 'lat': -27.48706, 'lon': -55.11994, 'pop': 56528, 'distance': 186.0821583121778}
# {'name': 'Olavarría', 'country': 'AR', 'admin1': 'Buenos Aires', 'lat': -36.89272, 'lon': -60.32254, 'pop': 86320, 'distance': 194.12323814413256}
# {'name': 'Paraná', 'country': 'AR', 'admin1': 'Entre Ríos Province', 'lat': -31.73271, 'lon': -60.52897, 'pop': 262295, 'distance': 192.56843536656208}
# {'name': 'Pergamino', 'country': 'AR', 'admin1': 'Buenos Aires', 'lat': -33.88995, 'lon': -60.57357, 'pop': 87652, 'distance': 193.3264312052695}
# {'name': 'Pilar', 'country': 'AR', 'admin1': 'Buenos Aires', 'lat': -34.45866, 'lon': -58.9142, 'pop': 226517, 'distance': 191.9586678821303}
# {'name': 'Posadas', 'country': 'AR', 'admin1': 'Misiones Province', 'lat': -27.36708, 'lon': -55.89608, 'pop': 323739, 'distance': 186.78114746844662}
# {'name': 'Presidencia Roque Sáenz Peña', 'country': 'AR', 'admin1': 'Chaco Province', 'lat': -26.78522, 'lon': -60.43876, 'pop': 81879, 'distance': 190.92227796007987}
# {'name': 'Puerto Eldorado', 'country': 'AR', 'admin1': 'Misiones Province', 'lat': -26.40843, 'lon': -54.69463, 'pop': 54189, 'distance': 185.34039498624847}
# {'name': 'Puerto Madryn', 'country': 'AR', 'admin1': 'Chubut Province', 'lat': -42.7692, 'lon': -65.03851, 'pop': 64555, 'distance': 200.6382337825503}
# {'name': 'Punta Alta', 'country': 'AR', 'admin1': 'Buenos Aires', 'lat': -38.87588, 'lon': -62.07359, 'pop': 57209, 'distance': 196.4627450061016}
# {'name': 'Quilmes', 'country': 'AR', 'admin1': 'Buenos Aires', 'lat': -34.72904, 'lon': -58.26374, 'pop': 230000, 'distance': 191.44057587363133}
# {'name': 'Rafaela', 'country': 'AR', 'admin1': 'Santa Fe Province', 'lat': -31.25033, 'lon': -61.4867, 'pop': 88713, 'distance': 193.31736785648644}
# {'name': 'Reconquista', 'country': 'AR', 'admin1': 'Santa Fe Province', 'lat': -29.15, 'lon': -59.65, 'pop': 90184, 'distance': 190.90556394377822}
# {'name': 'Resistencia', 'country': 'AR', 'admin1': 'Chaco Province', 'lat': -27.46056, 'lon': -58.98389, 'pop': 387158, 'distance': 189.7444755146534}
# {'name': 'Río Cuarto', 'country': 'AR', 'admin1': 'Córdoba Province', 'lat': -33.13067, 'lon': -64.34992, 'pop': 153757, 'distance': 196.63646631037818}
# {'name': 'Río Gallegos', 'country': 'AR', 'admin1': 'Santa Cruz Province', 'lat': -51.62261, 'lon': -69.21813, 'pop': 85700, 'distance': 207.89582797796837}
# {'name': 'Río Grande', 'country': 'AR', 'admin1': 'Tierra del Fuego Province', 'lat': -53.78769, 'lon': -67.70946, 'pop': 52681, 'distance': 207.39102058950988}
# {'name': 'Río Tercero', 'country': 'AR', 'admin1': 'Córdoba Province', 'lat': -32.17301, 'lon': -64.11405, 'pop': 53389, 'distance': 196.10192043069085}
# {'name': 'Rosario', 'country': 'AR', 'admin1': 'Santa Fe Province', 'lat': -32.94682, 'lon': -60.63932, 'pop': 1173533, 'distance': 193.0728398749705}
# {'name': 'Salta', 'country': 'AR', 'admin1': 'Salta Province', 'lat': -24.7859, 'lon': -65.41166, 'pop': 512686, 'distance': 195.0825511387751}
# {'name': 'San Carlos de Bariloche', 'country': 'AR', 'admin1': 'Río Negro Province', 'lat': -41.14557, 'lon': -71.30822, 'pop': 95394, 'distance': 205.9027336742339}
# {'name': 'San Fernando del Valle de Catamarca', 'country': 'AR', 'admin1': 'Catamarca Province', 'lat': -28.46957, 'lon': -65.78524, 'pop': 188812, 'distance': 196.52776696511387}
# {'name': 'San Francisco', 'country': 'AR', 'admin1': 'Córdoba Province', 'lat': -31.42797, 'lon': -62.08266, 'pop': 59062, 'distance': 193.93875890382122}
# {'name': 'San Juan', 'country': 'AR', 'admin1': 'San Juan Province', 'lat': -31.5375, 'lon': -68.53639, 'pop': 447048, 'distance': 200.09166270807214}
# {'name': 'San Luis', 'country': 'AR', 'admin1': 'San Luis Province', 'lat': -33.29501, 'lon': -66.33563, 'pop': 183982, 'distance': 198.56722531850266}
# {'name': 'San Martín', 'country': 'AR', 'admin1': 'Mendoza Province', 'lat': -33.08103, 'lon': -68.46814, 'pop': 82549, 'distance': 200.51650656991436}
# {'name': 'San Miguel', 'country': 'AR', 'admin1': 'Buenos Aires', 'lat': -34.54335, 'lon': -58.71229, 'pop': 157532, 'distance': 191.79798022019784}
# {'name': 'San Miguel de Tucumán', 'country': 'AR', 'admin1': 'Tucumán Province', 'lat': -26.82414, 'lon': -65.2226, 'pop': 781023, 'distance': 195.49692766712522}
# {'name': 'San Nicolás de los Arroyos', 'country': 'AR', 'admin1': 'Buenos Aires', 'lat': -33.33425, 'lon': -60.2108, 'pop': 127742, 'distance': 192.79811335321853}
# {'name': 'San Pedro de Jujuy', 'country': 'AR', 'admin1': 'Jujuy Province', 'lat': -24.23127, 'lon': -64.86614, 'pop': 58430, 'distance': 194.4011241192296}
# {'name': 'San Rafael', 'country': 'AR', 'admin1': 'Mendoza Province', 'lat': -34.61772, 'lon': -68.33007, 'pop': 109163, 'distance': 200.88412577428937}
# {'name': 'San Ramón de la Nueva Orán', 'country': 'AR', 'admin1': 'Salta Province', 'lat': -23.13705, 'lon': -64.32426, 'pop': 74059, 'distance': 193.57169384885617}
# {'name': 'San Salvador de Jujuy', 'country': 'AR', 'admin1': 'Jujuy Province', 'lat': -24.19457, 'lon': -65.29712, 'pop': 305891, 'distance': 194.80379326577935}
# {'name': 'Santa Fe', 'country': 'AR', 'admin1': 'Santa Fe Province', 'lat': -31.64881, 'lon': -60.70868, 'pop': 489505, 'distance': 192.71089116987784}
# {'name': 'Santa Rosa', 'country': 'AR', 'admin1': 'La Pampa Province', 'lat': -36.61667, 'lon': -64.28333, 'pop': 111424, 'distance': 197.74220327376807}
# {'name': 'Santiago del Estero', 'country': 'AR', 'admin1': 'Santiago del Estero Province', 'lat': -27.79511, 'lon': -64.26149, 'pop': 354692, 'distance': 194.87123054091745}
# {'name': 'Santo Tomé', 'country': 'AR', 'admin1': 'Santa Fe Province', 'lat': -31.66274, 'lon': -60.7653, 'pop': 59072, 'distance': 192.7689578845391}
# {'name': 'Tandil', 'country': 'AR', 'admin1': 'Buenos Aires', 'lat': -37.32167, 'lon': -59.13316, 'pop': 104325, 'distance': 193.16172912205073}
# {'name': 'Tartagal', 'country': 'AR', 'admin1': 'Salta Province', 'lat': -22.51637, 'lon': -63.80131, 'pop': 60819, 'distance': 192.8960088441049}
# {'name': 'Trelew', 'country': 'AR', 'admin1': 'Chubut Province', 'lat': -43.24895, 'lon': -65.30505, 'pop': 93442, 'distance': 201.0632100063087}
# {'name': 'Ushuaia', 'country': 'AR', 'admin1': 'Tierra del Fuego Province', 'lat': -54.81084, 'lon': -68.31591, 'pop': 58028, 'distance': 208.3646973518415}
# {'name': 'Venado Tuerto', 'country': 'AR', 'admin1': 'Santa Fe Province', 'lat': -33.74556, 'lon': -61.96885, 'pop': 72340, 'distance': 194.59250692222582}
# {'name': 'Villa Carlos Paz', 'country': 'AR', 'admin1': 'Córdoba Province', 'lat': -31.42414, 'lon': -64.49778, 'pop': 69451, 'distance': 196.2247202860924}
# {'name': 'Villa María', 'country': 'AR', 'admin1': 'Córdoba Province', 'lat': -32.40751, 'lon': -63.24016, 'pop': 92453, 'distance': 195.35141415162906}
# {'name': 'Villa Mercedes', 'country': 'AR', 'admin1': 'San Luis Province', 'lat': -33.67571, 'lon': -65.45783, 'pop': 96781, 'distance': 197.86179836637743}
# {'name': 'Yerba Buena', 'country': 'AR', 'admin1': 'Tucumán Province', 'lat': -26.81667, 'lon': -65.31667, 'pop': 50783, 'distance': 195.58454059307707}
# {'name': 'Zárate', 'country': 'AR', 'admin1': 'Buenos Aires', 'lat': -34.09814, 'lon': -59.02858, 'pop': 88781, 'distance': 191.94315994329986}
# {'name': 'Graz', 'country': 'AT', 'admin1': 'Steiermark', 'lat': 47.06667, 'lon': 15.45, 'pop': 222326, 'distance': 107.18561181784662}
# {'name': 'Innsbruck', 'country': 'AT', 'admin1': 'Tirol', 'lat': 47.26266, 'lon': 11.39454, 'pop': 132493, 'distance': 111.22622959618833}
# {'name': 'Klagenfurt am Wörthersee', 'country': 'AT', 'admin1': 'Kärnten', 'lat': 46.62472, 'lon': 14.30528, 'pop': 90610, 'distance': 108.25412356108382}
# {'name': 'Linz', 'country': 'AT', 'admin1': 'Oberösterreich', 'lat': 48.30639, 'lon': 14.28611, 'pop': 204846, 'distance': 108.5250926347976}
# {'name': 'Salzburg', 'country': 'AT', 'admin1': 'Salzburg', 'lat': 47.79941, 'lon': 13.04399, 'pop': 153377, 'distance': 109.67412549120691}
# {'name': 'Vienna', 'country': 'AT', 'admin1': 'Wien', 'lat': 48.20849, 'lon': 16.37208, 'pop': 1691468, 'distance': 106.44997210461496}
# {'name': 'Villach', 'country': 'AT', 'admin1': 'Kärnten', 'lat': 46.61028, 'lon': 13.85583, 'pop': 58882, 'distance': 108.69697461997966}
# {'name': 'Adelaide', 'country': 'AU', 'admin1': 'State of South Australia', 'lat': -34.92866, 'lon': 138.59863, 'pop': 1225235, 'distance': 68.33548174044945}
# {'name': 'Adelaide Hills', 'country': 'AU', 'admin1': 'State of South Australia', 'lat': -34.91119, 'lon': 138.70735, 'pop': 60394, 'distance': 68.3459283625016}
# {'name': 'Ballarat', 'country': 'AU', 'admin1': 'State of Victoria', 'lat': -37.56622, 'lon': 143.84957, 'pop': 97937, 'distance': 72.34106162971139}
# {'name': 'Bendigo', 'country': 'AU', 'admin1': 'State of Victoria', 'lat': -36.75818, 'lon': 144.28024, 'pop': 100617, 'distance': 71.70904185744222}
# {'name': 'Brisbane', 'country': 'AU', 'admin1': 'State of Queensland', 'lat': -27.46794, 'lon': 153.02809, 'pop': 2189878, 'distance': 66.64234145816381}
# {'name': 'Bunbury', 'country': 'AU', 'admin1': 'State of Western Australia', 'lat': -33.32711, 'lon': 115.64137, 'pop': 68248, 'distance': 64.81087783701899}
# {'name': 'Bundaberg', 'country': 'AU', 'admin1': 'State of Queensland', 'lat': -24.86621, 'lon': 152.3479, 'pop': 70826, 'distance': 64.03197791018563}
# {'name': 'Cairns', 'country': 'AU', 'admin1': 'State of Queensland', 'lat': -16.92366, 'lon': 145.76613, 'pop': 153075, 'distance': 53.934293618247196}
# {'name': 'Canberra', 'country': 'AU', 'admin1': 'Australian Capital Territory', 'lat': -35.28346, 'lon': 149.12807, 'pop': 367752, 'distance': 72.03217979252398}
# {'name': 'Darwin', 'country': 'AU', 'admin1': 'Northern Territory', 'lat': -12.46113, 'lon': 130.84185, 'pop': 129062, 'distance': 44.67986774808762}
# {'name': 'Geelong', 'country': 'AU', 'admin1': 'State of Victoria', 'lat': -38.14711, 'lon': 144.36069, 'pop': 226034, 'distance': 73.05227173446283}
# {'name': 'Gold Coast', 'country': 'AU', 'admin1': 'State of Queensland', 'lat': -28.00029, 'lon': 153.43088, 'pop': 591473, 'distance': 67.30205724532127}
# {'name': 'Hervey Bay', 'country': 'AU', 'admin1': 'State of Queensland', 'lat': -25.28762, 'lon': 152.76936, 'pop': 52230, 'distance': 64.60464011598238}
# {'name': 'Hobart', 'country': 'AU', 'admin1': 'State of Tasmania', 'lat': -42.87936, 'lon': 147.32941, 'pop': 216656, 'distance': 78.48803035698437}
# {'name': 'Launceston', 'country': 'AU', 'admin1': 'State of Tasmania', 'lat': -41.43876, 'lon': 147.13467, 'pop': 106153, 'distance': 77.06429987778063}
# {'name': 'Logan City', 'country': 'AU', 'admin1': 'State of Queensland', 'lat': -27.63917, 'lon': 153.10944, 'pop': 282673, 'distance': 66.83167728432753}
# {'name': 'Mackay', 'country': 'AU', 'admin1': 'State of Queensland', 'lat': -21.15345, 'lon': 149.16554, 'pop': 74219, 'distance': 59.25297676825443}
# {'name': 'Maitland', 'country': 'AU', 'admin1': 'State of New South Wales', 'lat': -32.73308, 'lon': 151.5574, 'pop': 67132, 'distance': 70.68416135546633}
# {'name': 'Mandurah', 'country': 'AU', 'admin1': 'State of Western Australia', 'lat': -32.5269, 'lon': 115.7217, 'pop': 83294, 'distance': 64.00668814134973}
# {'name': 'Melbourne', 'country': 'AU', 'admin1': 'State of Victoria', 'lat': -37.814, 'lon': 144.96332, 'pop': 4246375, 'distance': 72.92802561125593}
# {'name': 'Newcastle', 'country': 'AU', 'admin1': 'State of New South Wales', 'lat': -32.92953, 'lon': 151.7801, 'pop': 308308, 'distance': 70.9568399650386}
# {'name': 'Perth', 'country': 'AU', 'admin1': 'State of Western Australia', 'lat': -31.95224, 'lon': 115.8614, 'pop': 1896548, 'distance': 63.421881077804684}
# {'name': 'Rockhampton', 'country': 'AU', 'admin1': 'State of Queensland', 'lat': -23.38032, 'lon': 150.50595, 'pop': 61724, 'distance': 61.848341027902286}
# {'name': 'Rockingham', 'country': 'AU', 'admin1': 'State of Western Australia', 'lat': -32.27682, 'lon': 115.72978, 'pop': 108022, 'distance': 63.7568919622028}
# {'name': 'Sydney', 'country': 'AU', 'admin1': 'State of New South Wales', 'lat': -33.86785, 'lon': 151.20732, 'pop': 4627345, 'distance': 71.56630270701778}
# {'name': 'Toowoomba', 'country': 'AU', 'admin1': 'State of Queensland', 'lat': -27.56056, 'lon': 151.95386, 'pop': 131258, 'distance': 66.22242099295676}
# {'name': 'Townsville', 'country': 'AU', 'admin1': 'State of Queensland', 'lat': -19.26639, 'lon': 146.80569, 'pop': 196219, 'distance': 56.4942659599096}
# {'name': 'Wollongong', 'country': 'AU', 'admin1': 'State of New South Wales', 'lat': -34.424, 'lon': 150.89345, 'pop': 292190, 'distance': 71.94350828768708}
# {'name': 'Bakıxanov', 'country': 'AZ', 'admin1': 'Baku City', 'lat': 40.41894, 'lon': 49.96693, 'pop': 66686, 'distance': 72.08024228202413}
# {'name': 'Baku', 'country': 'AZ', 'admin1': 'Baku City', 'lat': 40.37767, 'lon': 49.89201, 'pop': 1116513, 'distance': 72.1493019876492}
# {'name': 'Ganja', 'country': 'AZ', 'admin1': 'Ganja City', 'lat': 40.68278, 'lon': 46.36056, 'pop': 313300, 'distance': 75.69106091054346}
# {'name': 'Lankaran', 'country': 'AZ', 'admin1': 'Lankaran Rayon', 'lat': 38.75428, 'lon': 48.85062, 'pop': 240300, 'distance': 72.99707029187678}
# {'name': 'Mingelchaur', 'country': 'AZ', 'admin1': 'Mingacevir City', 'lat': 40.76395, 'lon': 47.05953, 'pop': 95453, 'distance': 75.00790543371944}
# {'name': 'Nakhchivan', 'country': 'AZ', 'admin1': 'Nakhchivan Autonomous Republic', 'lat': 39.20889, 'lon': 45.41222, 'pop': 64754, 'distance': 76.4640875116842}
# {'name': 'Qaraçuxur', 'country': 'AZ', 'admin1': 'Baku City', 'lat': 40.39667, 'lon': 49.97361, 'pop': 72989, 'distance': 72.07077857637589}
# {'name': 'Saatlı', 'country': 'AZ', 'admin1': 'Saatly Rayon', 'lat': 39.93214, 'lon': 48.36892, 'pop': 87000, 'distance': 73.60628432644864}
# {'name': 'Sheki', 'country': 'AZ', 'admin1': 'Shaki city', 'lat': 41.19194, 'lon': 47.17056, 'pop': 63000, 'distance': 74.95350540920951}
# {'name': 'Şirvan', 'country': 'AZ', 'admin1': 'Shirvan', 'lat': 39.93778, 'lon': 48.929, 'pop': 70220, 'distance': 73.0508420936898}
# {'name': 'Sumqayıt', 'country': 'AZ', 'admin1': 'Sumqayit City', 'lat': 40.58972, 'lon': 49.66861, 'pop': 265150, 'distance': 72.39803303648864}
# {'name': 'Xankandi', 'country': 'AZ', 'admin1': 'Xankandi Sahari', 'lat': 39.8177, 'lon': 46.7528, 'pop': 53100, 'distance': 75.19812596134295}
# {'name': 'Yevlakh', 'country': 'AZ', 'admin1': 'Yevlakh City', 'lat': 40.61832, 'lon': 47.15014, 'pop': 127400, 'distance': 74.89962396391853}
# {'name': 'Banja Luka', 'country': 'BA', 'admin1': 'Republika Srpska', 'lat': 44.77842, 'lon': 17.19386, 'pop': 221106, 'distance': 105.14178027825095}
# {'name': 'Bihać', 'country': 'BA', 'admin1': 'Federation of Bosnia and Herzegovina', 'lat': 44.81694, 'lon': 15.87083, 'pop': 75641, 'distance': 106.45881621994161}
# {'name': 'Mostar', 'country': 'BA', 'admin1': 'Federation of Bosnia and Herzegovina', 'lat': 43.34333, 'lon': 17.80806, 'pop': 104518, 'distance': 104.35633094178858}
# {'name': 'Sarajevo', 'country': 'BA', 'admin1': 'Federation of Bosnia and Herzegovina', 'lat': 43.84864, 'lon': 18.35644, 'pop': 696731, 'distance': 103.87189479662341}
# {'name': 'Tuzla', 'country': 'BA', 'admin1': 'Federation of Bosnia and Herzegovina', 'lat': 44.53842, 'lon': 18.66709, 'pop': 142486, 'distance': 103.64991411468175}
# {'name': 'Zenica', 'country': 'BA', 'admin1': 'Federation of Bosnia and Herzegovina', 'lat': 44.20169, 'lon': 17.90397, 'pop': 164423, 'distance': 104.36434351448295}
# {'name': 'Bridgetown', 'country': 'BB', 'admin1': 'Saint Michael', 'lat': 13.10732, 'lon': -59.62021, 'pop': 98511, 'distance': 181.9821130446696}
# {'name': 'Azimpur', 'country': 'BD', 'admin1': 'Dhaka Division', 'lat': 23.7298, 'lon': 90.3854, 'pop': 96641, 'distance': 31.96320629930608}
# {'name': 'Bagerhat', 'country': 'BD', 'admin1': 'Khulna Division', 'lat': 22.65657, 'lon': 89.79123, 'pop': 266388, 'distance': 32.804854551901315}
# {'name': 'Barisāl', 'country': 'BD', 'admin1': 'Barisal Division', 'lat': 22.70497, 'lon': 90.37013, 'pop': 202242, 'distance': 32.23356851556154}
# {'name': 'Bhairab Bāzār', 'country': 'BD', 'admin1': 'Dhaka Division', 'lat': 24.0524, 'lon': 90.9764, 'pop': 105457, 'distance': 31.313542041551294}
# {'name': 'Bhola', 'country': 'BD', 'admin1': 'Barisal Division', 'lat': 22.68759, 'lon': 90.64403, 'pop': 99079, 'distance': 31.974120067295054}
# {'name': 'Bibir Hat', 'country': 'BD', 'admin1': 'Chittagong', 'lat': 22.68347, 'lon': 91.79058, 'pop': 89030, 'distance': 30.87182568480361}
# {'name': 'Bogra', 'country': 'BD', 'admin1': 'Rājshāhi Division', 'lat': 24.85098, 'lon': 89.37108, 'pop': 210000, 'distance': 32.71340680299134}
# {'name': 'Chittagong', 'country': 'BD', 'admin1': 'Chittagong', 'lat': 22.3384, 'lon': 91.83168, 'pop': 3920222, 'distance': 30.929672641280895}
# {'name': 'Comilla', 'country': 'BD', 'admin1': 'Chittagong', 'lat': 23.46186, 'lon': 91.18503, 'pop': 389411, 'distance': 31.251872467269866}
# {'name': 'Cox’s Bāzār', 'country': 'BD', 'admin1': 'Chittagong', 'lat': 21.43973, 'lon': 92.00955, 'pop': 253788, 'distance': 31.030820998165677}
# {'name': 'Dhaka', 'country': 'BD', 'admin1': 'Dhaka Division', 'lat': 23.7104, 'lon': 90.40744, 'pop': 10356500, 'distance': 31.946336912027967}
# {'name': 'Dinājpur', 'country': 'BD', 'admin1': 'Rangpur Division', 'lat': 25.62745, 'lon': 88.63779, 'pop': 206234, 'distance': 33.293716737934204}
# {'name': 'Farīdpur', 'country': 'BD', 'admin1': 'Dhaka Division', 'lat': 23.60612, 'lon': 89.84064, 'pop': 112187, 'distance': 32.52178080404578}
# {'name': 'Feni', 'country': 'BD', 'admin1': 'Chittagong', 'lat': 23.0144, 'lon': 91.3966, 'pop': 84028, 'distance': 31.161830602260835}
# {'name': 'Habiganj', 'country': 'BD', 'admin1': 'Sylhet Division', 'lat': 24.38044, 'lon': 91.41299, 'pop': 88760, 'distance': 30.8142204975771}
# {'name': 'Ishurdi', 'country': 'BD', 'admin1': 'Rājshāhi Division', 'lat': 24.12858, 'lon': 89.06573, 'pop': 81995, 'distance': 33.15995734735647}
# {'name': 'Jamālpur', 'country': 'BD', 'admin1': 'Mymensingh Division', 'lat': 24.91965, 'lon': 89.94812, 'pop': 167900, 'distance': 32.134073931085986}
# {'name': 'Jessore', 'country': 'BD', 'admin1': 'Khulna Division', 'lat': 23.16971, 'lon': 89.21371, 'pop': 243987, 'distance': 33.234635912291864}
# {'name': 'Joypur Hāt', 'country': 'BD', 'admin1': 'Rājshāhi Division', 'lat': 25.10147, 'lon': 89.02734, 'pop': 73068, 'distance': 33.00326014624768}
# {'name': 'Khagrachhari', 'country': 'BD', 'admin1': 'Chittagong', 'lat': 23.10787, 'lon': 91.97007, 'pop': 50364, 'distance': 30.584051892491285}
# {'name': 'Khulna', 'country': 'BD', 'admin1': 'Khulna Division', 'lat': 22.80979, 'lon': 89.56439, 'pop': 1342339, 'distance': 32.984468535566855}
# {'name': 'Kishorganj', 'country': 'BD', 'admin1': 'Dhaka Division', 'lat': 24.43944, 'lon': 90.78291, 'pop': 90690, 'distance': 31.416093519896776}
# {'name': 'Kushtia', 'country': 'BD', 'admin1': 'Khulna Division', 'lat': 23.9028, 'lon': 89.11943, 'pop': 135724, 'distance': 33.15661169982995}
# {'name': 'Lākshām', 'country': 'BD', 'admin1': 'Chittagong', 'lat': 23.24018, 'lon': 91.12143, 'pop': 82290, 'distance': 31.36915813850445}
# {'name': 'Lakshmīpur', 'country': 'BD', 'admin1': 'Chittagong', 'lat': 22.9443, 'lon': 90.83005, 'pop': 61703, 'distance': 31.72694369280628}
# {'name': 'Lalmonirhat', 'country': 'BD', 'admin1': 'Rangpur Division', 'lat': 25.91719, 'lon': 89.44595, 'pop': 65127, 'distance': 32.44870613680922}
# {'name': 'Mādārīpur', 'country': 'BD', 'admin1': 'Dhaka Division', 'lat': 23.17097, 'lon': 90.20935, 'pop': 84789, 'distance': 32.269250118752375}
# {'name': 'Maulavi Bāzār', 'country': 'BD', 'admin1': 'Sylhet Division', 'lat': 24.48888, 'lon': 91.77075, 'pop': 57441, 'distance': 30.4413245866815}
# {'name': 'Mymensingh', 'country': 'BD', 'admin1': 'Mymensingh Division', 'lat': 24.75636, 'lon': 90.40646, 'pop': 225126, 'distance': 31.717648211990756}
# {'name': 'Nāgarpur', 'country': 'BD', 'admin1': 'Dhaka Division', 'lat': 24.05783, 'lon': 89.87696, 'pop': 238422, 'distance': 32.38355078248987}
# {'name': 'Narail', 'country': 'BD', 'admin1': 'Khulna Division', 'lat': 23.15509, 'lon': 89.49515, 'pop': 55112, 'distance': 32.96522716598508}
# {'name': 'Nārāyanganj', 'country': 'BD', 'admin1': 'Dhaka Division', 'lat': 23.61352, 'lon': 90.50298, 'pop': 223622, 'distance': 31.876469275884375}
# {'name': 'Narsingdi', 'country': 'BD', 'admin1': 'Dhaka Division', 'lat': 23.92298, 'lon': 90.71768, 'pop': 281080, 'distance': 31.595092453132654}
# {'name': 'Natore', 'country': 'BD', 'admin1': 'Rājshāhi Division', 'lat': 24.41112, 'lon': 88.98673, 'pop': 369138, 'distance': 33.177979974358}
# {'name': 'Nawābganj', 'country': 'BD', 'admin1': 'Rājshāhi Division', 'lat': 24.59025, 'lon': 88.27444, 'pop': 142361, 'distance': 33.83985316731295}
# {'name': 'Netrakona', 'country': 'BD', 'admin1': 'Mymensingh Division', 'lat': 24.88352, 'lon': 90.72898, 'pop': 79016, 'distance': 31.37603345447604}
# {'name': 'Pābna', 'country': 'BD', 'admin1': 'Rājshāhi Division', 'lat': 24.00644, 'lon': 89.2372, 'pop': 186781, 'distance': 33.018953650108294}
# {'name': 'Pālang', 'country': 'BD', 'admin1': 'Dhaka Division', 'lat': 23.21824, 'lon': 90.35076, 'pop': 67652, 'distance': 32.120520063199486}
# {'name': 'Paltan', 'country': 'BD', 'admin1': 'Dhaka Division', 'lat': 23.73625, 'lon': 90.41426, 'pop': 184492, 'distance': 31.93363845979503}
# {'name': 'Pār Naogaon', 'country': 'BD', 'admin1': 'Rājshāhi Division', 'lat': 24.80418, 'lon': 88.94875, 'pop': 192464, 'distance': 33.136784305627785}
# {'name': 'Patiya', 'country': 'BD', 'admin1': 'Chittagong', 'lat': 22.29543, 'lon': 91.979, 'pop': 51360, 'distance': 30.80101553825296}
# {'name': 'Pirojpur', 'country': 'BD', 'admin1': 'Barisal Division', 'lat': 22.57965, 'lon': 89.97521, 'pop': 54418, 'distance': 32.6475705118681}
# {'name': 'Puthia', 'country': 'BD', 'admin1': 'Rājshāhi Division', 'lat': 24.36537, 'lon': 88.83431, 'pop': 159406, 'distance': 33.33654835139655}
# {'name': 'Rāipur', 'country': 'BD', 'admin1': 'Chittagong', 'lat': 23.0391, 'lon': 90.76808, 'pop': 64652, 'distance': 31.762215371960444}
# {'name': 'Rājshāhi', 'country': 'BD', 'admin1': 'Rājshāhi Division', 'lat': 24.374, 'lon': 88.60114, 'pop': 700133, 'distance': 33.563005065917444}
# {'name': 'Rāmganj', 'country': 'BD', 'admin1': 'Chittagong', 'lat': 23.1006, 'lon': 90.84989, 'pop': 55241, 'distance': 31.667345676158273}
# {'name': 'Rangpur', 'country': 'BD', 'admin1': 'Rangpur Division', 'lat': 25.74664, 'lon': 89.25166, 'pop': 343122, 'distance': 32.66855027846201}
# {'name': 'Saidpur', 'country': 'BD', 'admin1': 'Rājshāhi Division', 'lat': 25.77769, 'lon': 88.89169, 'pop': 199422, 'distance': 33.01834886692247}
# {'name': 'Sandwīp', 'country': 'BD', 'admin1': 'Chittagong', 'lat': 22.51409, 'lon': 91.45491, 'pop': 52152, 'distance': 31.241327404887908}
# {'name': 'Sarishābāri', 'country': 'BD', 'admin1': 'Mymensingh Division', 'lat': 24.75127, 'lon': 89.83126, 'pop': 81325, 'distance': 32.28200229450615}
# {'name': 'Sātkania', 'country': 'BD', 'admin1': 'Chittagong', 'lat': 22.07639, 'lon': 92.04955, 'pop': 52005, 'distance': 30.7978354240846}
# {'name': 'Sātkhira', 'country': 'BD', 'admin1': 'Khulna Division', 'lat': 22.70817, 'lon': 89.07185, 'pop': 128918, 'distance': 33.48664876583801}
# {'name': 'Shāhzādpur', 'country': 'BD', 'admin1': 'Rājshāhi Division', 'lat': 24.17687, 'lon': 89.5988, 'pop': 102420, 'distance': 32.628965726331266}
# {'name': 'Sherpur', 'country': 'BD', 'admin1': 'Mymensingh Division', 'lat': 25.01881, 'lon': 90.01751, 'pop': 107419, 'distance': 32.04669218391502}
# {'name': 'Shibganj', 'country': 'BD', 'admin1': 'Rājshāhi Division', 'lat': 25.00146, 'lon': 89.32266, 'pop': 378701, 'distance': 32.73196890102397}
# {'name': 'Sirajganj', 'country': 'BD', 'admin1': 'Rājshāhi Division', 'lat': 24.45771, 'lon': 89.70802, 'pop': 127481, 'distance': 32.462649853973716}
# {'name': 'Sonārgaon', 'country': 'BD', 'admin1': 'Dhaka Division', 'lat': 23.65, 'lon': 90.61667, 'pop': 130000, 'distance': 31.75735903472611}
# {'name': 'Sylhet', 'country': 'BD', 'admin1': 'Sylhet Division', 'lat': 24.89904, 'lon': 91.87198, 'pop': 237000, 'distance': 30.25423499410951}
# {'name': 'Tāngāil', 'country': 'BD', 'admin1': 'Dhaka Division', 'lat': 24.24984, 'lon': 89.91655, 'pop': 180144, 'distance': 32.30295552955643}
# {'name': 'Thākurgaon', 'country': 'BD', 'admin1': 'Rangpur Division', 'lat': 26.03097, 'lon': 88.46989, 'pop': 71096, 'distance': 33.39413775666921}
# {'name': 'Tungi', 'country': 'BD', 'admin1': 'Dhaka Division', 'lat': 23.89154, 'lon': 90.40232, 'pop': 337579, 'distance': 31.90921271686282}
# {'name': 'Tungipāra', 'country': 'BD', 'admin1': 'Dhaka Division', 'lat': 22.89983, 'lon': 89.90326, 'pop': 62210, 'distance': 32.63384099906261}
# {'name': 'Aalst', 'country': 'BE', 'admin1': 'Flanders', 'lat': 50.93604, 'lon': 4.0355, 'pop': 77534, 'distance': 119.06591576074995}
# {'name': 'Antwerpen', 'country': 'BE', 'admin1': 'Flanders', 'lat': 51.21989, 'lon': 4.40346, 'pop': 459805, 'distance': 118.75052078449552}
# {'name': 'Brugge', 'country': 'BE', 'admin1': 'Flanders', 'lat': 51.20892, 'lon': 3.22424, 'pop': 116709, 'distance': 119.91123537301415}
# {'name': 'Brussels', 'country': 'BE', 'admin1': 'Bruxelles-Capitale', 'lat': 50.85045, 'lon': 4.34878, 'pop': 1019022, 'distance': 118.74279293940876}
# {'name': 'Charleroi', 'country': 'BE', 'admin1': 'Wallonia', 'lat': 50.41136, 'lon': 4.44448, 'pop': 200132, 'distance': 118.57656175803041}
# {'name': 'Deurne', 'country': 'BE', 'admin1': 'Flanders', 'lat': 51.22134, 'lon': 4.46595, 'pop': 78747, 'distance': 118.6891680105076}
# {'name': 'Genk', 'country': 'BE', 'admin1': 'Flanders', 'lat': 50.965, 'lon': 5.50082, 'pop': 63666, 'distance': 117.62592771385907}
# {'name': 'Gent', 'country': 'BE', 'admin1': 'Flanders', 'lat': 51.05, 'lon': 3.71667, 'pop': 231493, 'distance': 119.39922855220004}
# {'name': 'Hasselt', 'country': 'BE', 'admin1': 'Flanders', 'lat': 50.93106, 'lon': 5.33781, 'pop': 69222, 'distance': 117.78094427456463}
# {'name': 'Kortrijk', 'country': 'BE', 'admin1': 'Flanders', 'lat': 50.82803, 'lon': 3.26487, 'pop': 73879, 'distance': 119.80825492482644}
# {'name': 'La Louvière', 'country': 'BE', 'admin1': 'Wallonia', 'lat': 50.48657, 'lon': 4.18785, 'pop': 76668, 'distance': 118.84198472916296}
# {'name': 'Leuven', 'country': 'BE', 'admin1': 'Flanders', 'lat': 50.87959, 'lon': 4.70093, 'pop': 92892, 'distance': 118.40033615304392}
# {'name': 'Liège', 'country': 'BE', 'admin1': 'Wallonia', 'lat': 50.63373, 'lon': 5.56749, 'pop': 182597, 'distance': 117.50502514958669}
# {'name': 'Mechelen', 'country': 'BE', 'admin1': 'Flanders', 'lat': 51.02574, 'lon': 4.47762, 'pop': 77530, 'distance': 118.64485975795158}
# {'name': 'Mons', 'country': 'BE', 'admin1': 'Wallonia', 'lat': 50.45413, 'lon': 3.95229, 'pop': 91277, 'distance': 119.06919142053918}
# {'name': 'Mouscron', 'country': 'BE', 'admin1': 'Wallonia', 'lat': 50.74497, 'lon': 3.20639, 'pop': 52069, 'distance': 119.85238931849211}
# {'name': 'Namur', 'country': 'BE', 'admin1': 'Wallonia', 'lat': 50.4669, 'lon': 4.86746, 'pop': 106284, 'distance': 118.1682094163333}
# {'name': 'Ostend', 'country': 'BE', 'admin1': 'Flanders', 'lat': 51.21551, 'lon': 2.927, 'pop': 69011, 'distance': 120.20542346228683}
# {'name': 'Roeselare', 'country': 'BE', 'admin1': 'Flanders', 'lat': 50.94653, 'lon': 3.12269, 'pop': 56016, 'distance': 119.9679465441207}
# {'name': 'Seraing', 'country': 'BE', 'admin1': 'Wallonia', 'lat': 50.58362, 'lon': 5.50115, 'pop': 60737, 'distance': 117.56219114455166}
# {'name': 'Sint-Niklaas', 'country': 'BE', 'admin1': 'Flanders', 'lat': 51.16509, 'lon': 4.1437, 'pop': 69010, 'distance': 118.9973828537691}
# {'name': 'Tournai', 'country': 'BE', 'admin1': 'Wallonia', 'lat': 50.60715, 'lon': 3.38932, 'pop': 67721, 'distance': 119.64950010882829}
# {'name': 'Verviers', 'country': 'BE', 'admin1': 'Wallonia', 'lat': 50.58907, 'lon': 5.86241, 'pop': 52824, 'distance': 117.2067795728771}
# {'name': 'Banfora', 'country': 'BF', 'admin1': 'Cascades Region', 'lat': 10.63333, 'lon': -4.76667, 'pop': 60288, 'distance': 127.89286475407846}
# {'name': 'Bobo-Dioulasso', 'country': 'BF', 'admin1': 'High-Basins Region', 'lat': 11.17715, 'lon': -4.2979, 'pop': 360106, 'distance': 127.34349730876131}
# {'name': 'Koudougou', 'country': 'BF', 'admin1': 'Centre-Ouest', 'lat': 12.25263, 'lon': -2.36272, 'pop': 87347, 'distance': 125.2654417809497}
# {'name': 'Ouagadougou', 'country': 'BF', 'admin1': 'Centre', 'lat': 12.36566, 'lon': -1.53388, 'pop': 1086505, 'distance': 124.42904468007941}
# {'name': 'Ouahigouya', 'country': 'BF', 'admin1': 'Nord', 'lat': 13.58278, 'lon': -2.42158, 'pop': 61096, 'distance': 125.12919343639678}
# {'name': 'Asenovgrad', 'country': 'BG', 'admin1': 'Plovdiv', 'lat': 42.01667, 'lon': 24.86667, 'pop': 52170, 'distance': 97.19267859738511}
# {'name': 'Blagoevgrad', 'country': 'BG', 'admin1': 'Blagoevgrad', 'lat': 42.01667, 'lon': 23.1, 'pop': 71306, 'distance': 98.94861352119139}
# {'name': 'Burgas', 'country': 'BG', 'admin1': 'Burgas', 'lat': 42.50606, 'lon': 27.46781, 'pop': 195966, 'distance': 94.66515800550962}
# {'name': 'Dobrich', 'country': 'BG', 'admin1': 'Oblast Dobrich', 'lat': 43.56667, 'lon': 27.83333, 'pop': 94831, 'distance': 94.43503329472279}
# {'name': 'Gabrovo', 'country': 'BG', 'admin1': 'Gabrovo', 'lat': 42.87472, 'lon': 25.33417, 'pop': 66175, 'distance': 96.82759412988686}
# {'name': 'Haskovo', 'country': 'BG', 'admin1': 'Haskovo', 'lat': 41.93415, 'lon': 25.55557, 'pop': 79699, 'distance': 96.49887580964351}
# {'name': 'Kardzhali', 'country': 'BG', 'admin1': 'Oblast Kardzhali', 'lat': 41.65, 'lon': 25.36667, 'pop': 51000, 'distance': 96.65554214767253}
# {'name': 'Kazanlak', 'country': 'BG', 'admin1': 'Oblast Stara Zagora', 'lat': 42.61667, 'lon': 25.4, 'pop': 55196, 'distance': 96.73150666544021}
# {'name': 'Pazardzhik', 'country': 'BG', 'admin1': 'Pazardzhik', 'lat': 42.2, 'lon': 24.33333, 'pop': 75977, 'distance': 97.74315746537606}
# {'name': 'Pernik', 'country': 'BG', 'admin1': 'Pernik', 'lat': 42.6, 'lon': 23.03333, 'pop': 82467, 'distance': 99.08017638913094}
# {'name': 'Pleven', 'country': 'BG', 'admin1': 'Oblast Pleven', 'lat': 43.41667, 'lon': 24.61667, 'pop': 118675, 'distance': 97.60614441690954}
# {'name': 'Plovdiv', 'country': 'BG', 'admin1': 'Plovdiv', 'lat': 42.15, 'lon': 24.75, 'pop': 340494, 'distance': 97.32350818117892}
# {'name': 'Ruse', 'country': 'BG', 'admin1': 'Oblast Ruse', 'lat': 43.84872, 'lon': 25.9534, 'pop': 156238, 'distance': 96.33570773065199}
# {'name': 'Shumen', 'country': 'BG', 'admin1': 'Oblast Shumen', 'lat': 43.27064, 'lon': 26.92286, 'pop': 87283, 'distance': 95.29988700694456}
# {'name': 'Sliven', 'country': 'BG', 'admin1': 'Oblast Sliven', 'lat': 42.68583, 'lon': 26.32917, 'pop': 96368, 'distance': 95.81711781756013}
# {'name': 'Sofia', 'country': 'BG', 'admin1': 'Sofia-Grad', 'lat': 42.69751, 'lon': 23.32415, 'pop': 1152556, 'distance': 98.80256359261232}
# {'name': 'Stara Zagora', 'country': 'BG', 'admin1': 'Oblast Stara Zagora', 'lat': 42.43278, 'lon': 25.64194, 'pop': 143431, 'distance': 96.46971290186366}
# {'name': 'Varna', 'country': 'BG', 'admin1': 'Varna', 'lat': 43.21667, 'lon': 27.91667, 'pop': 312770, 'distance': 94.30725568022115}
# {'name': 'Veliko Tŭrnovo', 'country': 'BG', 'admin1': 'Oblast Veliko Tarnovo', 'lat': 43.08124, 'lon': 25.62904, 'pop': 66217, 'distance': 96.56001982974527}
# {'name': 'Vidin', 'country': 'BG', 'admin1': 'Oblast Vidin', 'lat': 43.99159, 'lon': 22.88236, 'pop': 54409, 'distance': 99.39932313998372}
# {'name': 'Vratsa', 'country': 'BG', 'admin1': 'Oblast Vratsa', 'lat': 43.21, 'lon': 23.5625, 'pop': 64941, 'distance': 98.62680942341184}
# {'name': 'Yambol', 'country': 'BG', 'admin1': 'Oblast Yambol', 'lat': 42.48333, 'lon': 26.5, 'pop': 80116, 'distance': 95.62345819617538}
# {'name': 'Al Muharraq', 'country': 'BH', 'admin1': 'Muharraq Governorate', 'lat': 26.25722, 'lon': 50.61194, 'pop': 97458, 'distance': 71.01988414559968}
# {'name': 'Ar Rifā‘', 'country': 'BH', 'admin1': 'Southern Governorate', 'lat': 26.13, 'lon': 50.555, 'pop': 79550, 'distance': 71.08568507014617}
# {'name': 'Dār Kulayb', 'country': 'BH', 'admin1': 'Southern Governorate', 'lat': 26.06861, 'lon': 50.50389, 'pop': 65466, 'distance': 71.14108472901577}
# {'name': 'Madīnat Ḩamad', 'country': 'BH', 'admin1': 'Northern Governorate', 'lat': 26.11528, 'lon': 50.50694, 'pop': 52718, 'distance': 71.13467695447841}
# {'name': 'Manama', 'country': 'BH', 'admin1': 'Capital Governorate', 'lat': 26.22787, 'lon': 50.58565, 'pop': 147074, 'distance': 71.0481669793852}
# {'name': 'Bujumbura', 'country': 'BI', 'admin1': 'Bujumbura Mairie Province', 'lat': -3.38193, 'lon': 29.36142, 'pop': 331700, 'distance': 98.38311997752511}
# {'name': 'Muyinga', 'country': 'BI', 'admin1': 'Muyinga Province', 'lat': -2.8451, 'lon': 30.3414, 'pop': 71076, 'distance': 97.2770683231048}
# {'name': 'Abomey', 'country': 'BJ', 'admin1': 'Zou Department', 'lat': 7.18286, 'lon': 1.99119, 'pop': 82154, 'distance': 121.86149456168056}
# {'name': 'Abomey-Calavi', 'country': 'BJ', 'admin1': 'Atlantique Department', 'lat': 6.44852, 'lon': 2.35566, 'pop': 385755, 'distance': 121.65162513279468}
# {'name': 'Bohicon', 'country': 'BJ', 'admin1': 'Zou Department', 'lat': 7.17826, 'lon': 2.0667, 'pop': 125092, 'distance': 121.78837734008611}
# {'name': 'Djougou', 'country': 'BJ', 'admin1': 'Donga', 'lat': 9.70853, 'lon': 1.66598, 'pop': 237040, 'distance': 121.7085916775907}
# {'name': 'Kandi', 'country': 'BJ', 'admin1': 'Alibori', 'lat': 11.13417, 'lon': 2.93861, 'pop': 109701, 'distance': 120.20977406644187}
# {'name': 'Lokossa', 'country': 'BJ', 'admin1': 'Mono', 'lat': 6.63869, 'lon': 1.71674, 'pop': 86971, 'distance': 122.23883860133529}
# {'name': 'Natitingou', 'country': 'BJ', 'admin1': 'Atakora Department', 'lat': 10.30416, 'lon': 1.37962, 'pop': 80892, 'distance': 121.88682039907842}
# {'name': 'Nikki', 'country': 'BJ', 'admin1': 'Borgou Department', 'lat': 9.94009, 'lon': 3.21075, 'pop': 54009, 'distance': 120.14722376972762}
# {'name': 'Ouidah', 'country': 'BJ', 'admin1': 'Atlantique Department', 'lat': 6.36307, 'lon': 2.08506, 'pop': 83503, 'distance': 121.93395945233017}
# {'name': 'Parakou', 'country': 'BJ', 'admin1': 'Borgou Department', 'lat': 9.33716, 'lon': 2.63031, 'pop': 163753, 'distance': 120.82628034192768}
# ...
# {'name': 'Bloemfontein', 'country': 'ZA', 'admin1': 'Free State', 'lat': -29.12107, 'lon': 26.214, 'pop': 463064, 'distance': 112.75080316036644}
# {'name': 'Boksburg', 'country': 'ZA', 'admin1': 'Gauteng', 'lat': -26.21197, 'lon': 28.25958, 'pop': 445168, 'distance': 109.47439360538381}
# {'name': 'Bothaville', 'country': 'ZA', 'admin1': 'Free State', 'lat': -27.3887, 'lon': 26.61701, 'pop': 71934, 'distance': 111.49020005520171}
# {'name': 'Botshabelo', 'country': 'ZA', 'admin1': 'Free State', 'lat': -29.26737, 'lon': 26.72595, 'pop': 309714, 'distance': 112.39734500165119}
# {'name': 'Brakpan', 'country': 'ZA', 'admin1': 'Gauteng', 'lat': -26.23656, 'lon': 28.36938, 'pop': 305692, 'distance': 109.39384691668359}
# {'name': 'Brits', 'country': 'ZA', 'admin1': 'Province of North West', 'lat': -25.63473, 'lon': 27.78022, 'pop': 122497, 'distance': 109.58216310316246}
# {'name': 'Cape Town', 'country': 'ZA', 'admin1': 'Western Cape', 'lat': -33.92584, 'lon': 18.42322, 'pop': 3433441, 'distance': 121.9034370950598}
# {'name': 'Carletonville', 'country': 'ZA', 'admin1': 'Gauteng', 'lat': -26.36094, 'lon': 27.39767, 'pop': 182304, 'distance': 110.2867955946572}
# {'name': 'Centurion', 'country': 'ZA', 'admin1': 'Gauteng', 'lat': -25.85891, 'lon': 28.18577, 'pop': 233386, 'distance': 109.3525284752072}
# {'name': 'Delmas', 'country': 'ZA', 'admin1': 'Mpumalanga', 'lat': -26.1466, 'lon': 28.68322, 'pop': 92046, 'distance': 109.07956932999875}
# {'name': 'Dundee', 'country': 'ZA', 'admin1': 'Province of KwaZulu-Natal', 'lat': -28.16678, 'lon': 30.23371, 'pop': 84413, 'distance': 108.85281509415593}
# {'name': 'Durban', 'country': 'ZA', 'admin1': 'Province of KwaZulu-Natal', 'lat': -29.8579, 'lon': 31.0292, 'pop': 3120282, 'distance': 109.12451502808156}
# {'name': 'East London', 'country': 'ZA', 'admin1': 'Eastern Cape', 'lat': -33.01529, 'lon': 27.91162, 'pop': 478676, 'distance': 113.47860647573049}
# {'name': 'eMbalenhle', 'country': 'ZA', 'admin1': 'Mpumalanga', 'lat': -26.53333, 'lon': 29.06667, 'pop': 141741, 'distance': 108.95812269828532}
# {'name': 'Fochville', 'country': 'ZA', 'admin1': 'Province of North West', 'lat': -26.48862, 'lon': 27.49387, 'pop': 62416, 'distance': 110.27152876360108}
# {'name': 'Fort Beaufort', 'country': 'ZA', 'admin1': 'Eastern Cape', 'lat': -32.77477, 'lon': 26.63376, 'pop': 58419, 'distance': 114.3995742979409}
# {'name': 'Ga-Rankuwa', 'country': 'ZA', 'admin1': 'Province of North West', 'lat': -25.61692, 'lon': 27.99471, 'pop': 68767, 'distance': 109.38960475823148}
# {'name': 'Graaff-Reinet', 'country': 'ZA', 'admin1': 'Eastern Cape', 'lat': -32.25215, 'lon': 24.53075, 'pop': 62896, 'distance': 115.86155130470591}
# {'name': 'Grahamstown', 'country': 'ZA', 'admin1': 'Eastern Cape', 'lat': -33.30422, 'lon': 26.53276, 'pop': 91548, 'distance': 114.78011168823457}
# {'name': 'Heidelberg', 'country': 'ZA', 'admin1': 'Gauteng', 'lat': -26.50476, 'lon': 28.35921, 'pop': 64199, 'distance': 109.5435990427688}
# {'name': 'Heilbron', 'country': 'ZA', 'admin1': 'Free State', 'lat': -27.28115, 'lon': 27.9709, 'pop': 55196, 'distance': 110.2836950152764}
# {'name': 'Johannesburg', 'country': 'ZA', 'admin1': 'Gauteng', 'lat': -26.20227, 'lon': 28.04363, 'pop': 2026469, 'distance': 109.65321602208027}
# {'name': 'Kimberley', 'country': 'ZA', 'admin1': 'Province of Northern Cape', 'lat': -28.73226, 'lon': 24.76232, 'pop': 142089, 'distance': 113.77436357201917}
# {'name': 'Klerksdorp', 'country': 'ZA', 'admin1': 'Province of North West', 'lat': -26.85213, 'lon': 26.66672, 'pop': 178921, 'distance': 111.16666886669807}
# {'name': 'Knysna', 'country': 'ZA', 'admin1': 'Western Cape', 'lat': -34.03627, 'lon': 23.04713, 'pop': 68659, 'distance': 118.08209712121902}
# {'name': 'Kraaifontein', 'country': 'ZA', 'admin1': 'Western Cape', 'lat': -33.84808, 'lon': 18.71723, 'pop': 57911, 'distance': 121.61341246416409}
# {'name': 'Kroonstad', 'country': 'ZA', 'admin1': 'Free State', 'lat': -27.65036, 'lon': 27.23488, 'pop': 103992, 'distance': 111.10350275832351}
# {'name': 'Krugersdorp', 'country': 'ZA', 'admin1': 'Gauteng', 'lat': -26.08577, 'lon': 27.77515, 'pop': 378821, 'distance': 109.82118804633376}
# {'name': 'Kutloanong', 'country': 'ZA', 'admin1': 'Free State', 'lat': -27.83333, 'lon': 26.75, 'pop': 95008, 'distance': 111.61171360912842}
# {'name': 'KwaDukuza', 'country': 'ZA', 'admin1': 'Province of KwaZulu-Natal', 'lat': -29.32816, 'lon': 31.28954, 'pop': 59899, 'distance': 108.61266278447832}
# {'name': 'Lichtenburg', 'country': 'ZA', 'admin1': 'Province of North West', 'lat': -26.152, 'lon': 26.15968, 'pop': 65863, 'distance': 111.23660526657942}
# {'name': 'Louis Trichardt', 'country': 'ZA', 'admin1': 'Limpopo', 'lat': -23.04385, 'lon': 29.90319, 'pop': 86854, 'distance': 106.42885216876954}
# {'name': 'Mabopane', 'country': 'ZA', 'admin1': 'Gauteng', 'lat': -25.49768, 'lon': 28.10065, 'pop': 97417, 'distance': 109.23714138477855}
# {'name': 'Middelburg', 'country': 'ZA', 'admin1': 'Mpumalanga', 'lat': -25.77507, 'lon': 29.46482, 'pop': 154706, 'distance': 108.21944036559097}
# {'name': 'Midrand', 'country': 'ZA', 'admin1': 'Gauteng', 'lat': -25.98953, 'lon': 28.12843, 'pop': 173009, 'distance': 109.46964955639258}
# {'name': 'Mokopane', 'country': 'ZA', 'admin1': 'Limpopo', 'lat': -24.19436, 'lon': 29.00974, 'pop': 101090, 'distance': 107.78538495417084}
# {'name': 'Mossel Bay', 'country': 'ZA', 'admin1': 'Western Cape', 'lat': -34.18307, 'lon': 22.14605, 'pop': 59031, 'distance': 118.91479003986089}
# {'name': 'Mpumalanga', 'country': 'ZA', 'admin1': 'Province of KwaZulu-Natal', 'lat': -29.81292, 'lon': 30.63646, 'pop': 140121, 'distance': 109.42509466013544}
# {'name': 'Mthatha', 'country': 'ZA', 'admin1': 'Eastern Cape', 'lat': -31.58893, 'lon': 28.78443, 'pop': 78663, 'distance': 111.95375054771233}
# {'name': 'Nelspruit', 'country': 'ZA', 'admin1': 'Mpumalanga', 'lat': -25.47448, 'lon': 30.97033, 'pop': 110159, 'distance': 106.78270024420107}
# {'name': 'Newcastle', 'country': 'ZA', 'admin1': 'Province of KwaZulu-Natal', 'lat': -27.75796, 'lon': 29.9318, 'pop': 404838, 'distance': 108.88396531363101}
# {'name': 'Nigel', 'country': 'ZA', 'admin1': 'Gauteng', 'lat': -26.43138, 'lon': 28.47713, 'pop': 140644, 'distance': 109.40471167470302}
# {'name': 'Orkney', 'country': 'ZA', 'admin1': 'Province of North West', 'lat': -26.98023, 'lon': 26.67272, 'pop': 145801, 'distance': 111.22852990540737}
# {'name': 'Oudtshoorn', 'country': 'ZA', 'admin1': 'Western Cape', 'lat': -33.60047, 'lon': 22.19955, 'pop': 61507, 'distance': 118.55055017272673}
# {'name': 'Paarl', 'country': 'ZA', 'admin1': 'Western Cape', 'lat': -33.73378, 'lon': 18.97523, 'pop': 190000, 'distance': 121.33430010021445}
# {'name': 'Parys', 'country': 'ZA', 'admin1': 'Free State', 'lat': -26.9033, 'lon': 27.45727, 'pop': 71319, 'distance': 110.52024518564234}
# {'name': 'Phalaborwa', 'country': 'ZA', 'admin1': 'Limpopo', 'lat': -23.94299, 'lon': 31.14107, 'pop': 109468, 'distance': 105.83174890836965}
# {'name': 'Phuthaditjhaba', 'country': 'ZA', 'admin1': 'Free State', 'lat': -28.52423, 'lon': 28.81582, 'pop': 84258, 'distance': 110.23712133315212}
# {'name': 'Piet Retief', 'country': 'ZA', 'admin1': 'Mpumalanga', 'lat': -27.00706, 'lon': 30.81323, 'pop': 84349, 'distance': 107.73641099947268}
# {'name': 'Pietermaritzburg', 'country': 'ZA', 'admin1': 'Province of KwaZulu-Natal', 'lat': -29.61679, 'lon': 30.39278, 'pop': 750845, 'distance': 109.5183562662374}
# {'name': 'Polokwane', 'country': 'ZA', 'admin1': 'Limpopo', 'lat': -23.90449, 'lon': 29.46885, 'pop': 123749, 'distance': 107.24257042727109}
# {'name': 'Port Elizabeth', 'country': 'ZA', 'admin1': 'Eastern Cape', 'lat': -33.96109, 'lon': 25.61494, 'pop': 967677, 'distance': 115.9084447048208}
# {'name': 'Port Shepstone', 'country': 'ZA', 'admin1': 'Province of KwaZulu-Natal', 'lat': -30.74137, 'lon': 30.45499, 'pop': 52793, 'distance': 110.09561860089165}
# {'name': 'Potchefstroom', 'country': 'ZA', 'admin1': 'Province of North West', 'lat': -26.71667, 'lon': 27.1, 'pop': 123669, 'distance': 110.72650297645862}
# {'name': 'Pretoria', 'country': 'ZA', 'admin1': 'Gauteng', 'lat': -25.74486, 'lon': 28.18783, 'pop': 1619438, 'distance': 109.29128056702099}
# {'name': 'Queenstown', 'country': 'ZA', 'admin1': 'Eastern Cape', 'lat': -31.89756, 'lon': 26.87533, 'pop': 105309, 'distance': 113.7101554017991}
# {'name': 'Randburg', 'country': 'ZA', 'admin1': 'Gauteng', 'lat': -26.0941, 'lon': 28.00123, 'pop': 337053, 'distance': 109.63274881161787}
# {'name': 'Randfontein', 'country': 'ZA', 'admin1': 'Gauteng', 'lat': -26.1844, 'lon': 27.70203, 'pop': 133654, 'distance': 109.93504073399573}
# {'name': 'Richards Bay', 'country': 'ZA', 'admin1': 'Province of KwaZulu-Natal', 'lat': -28.78301, 'lon': 32.03768, 'pop': 252968, 'distance': 107.6876593983605}
# {'name': 'Roodepoort', 'country': 'ZA', 'admin1': 'Gauteng', 'lat': -26.1625, 'lon': 27.8725, 'pop': 225000, 'distance': 109.77824524919315}
# {'name': 'Rustenburg', 'country': 'ZA', 'admin1': 'Province of North West', 'lat': -25.66756, 'lon': 27.24208, 'pop': 124064, 'distance': 110.05952005986943}
# {'name': 'Saldanha', 'country': 'ZA', 'admin1': 'Western Cape', 'lat': -33.01167, 'lon': 17.9442, 'pop': 68284, 'distance': 121.82410203499019}
# {'name': 'Sasolburg', 'country': 'ZA', 'admin1': 'Free State', 'lat': -26.81358, 'lon': 27.81695, 'pop': 77016, 'distance': 110.16719822012404}
# {'name': 'Schweizer-Reneke', 'country': 'ZA', 'admin1': 'Province of North West', 'lat': -27.18871, 'lon': 25.32931, 'pop': 70214, 'distance': 112.48365801318607}
# {'name': 'Soweto', 'country': 'ZA', 'admin1': 'Gauteng', 'lat': -26.26781, 'lon': 27.85849, 'pop': 1695047, 'distance': 109.84526869003417}
# {'name': 'Standerton', 'country': 'ZA', 'admin1': 'Mpumalanga', 'lat': -26.93366, 'lon': 29.24152, 'pop': 74021, 'distance': 109.02291790328307}
# {'name': 'Stellenbosch', 'country': 'ZA', 'admin1': 'Western Cape', 'lat': -33.93462, 'lon': 18.86676, 'pop': 94263, 'distance': 121.53348770802062}
# {'name': 'Stilfontein', 'country': 'ZA', 'admin1': 'Province of North West', 'lat': -26.84493, 'lon': 26.76829, 'pop': 93110, 'distance': 111.07630913824694}
# {'name': 'Tembisa', 'country': 'ZA', 'admin1': 'Gauteng', 'lat': -25.99636, 'lon': 28.2268, 'pop': 511655, 'distance': 109.38936757475108}
# {'name': 'Uitenhage', 'country': 'ZA', 'admin1': 'Eastern Cape', 'lat': -33.75757, 'lon': 25.3971, 'pop': 228912, 'distance': 115.97448488596835}
# {'name': 'Upington', 'country': 'ZA', 'admin1': 'Province of Northern Cape', 'lat': -28.44776, 'lon': 21.25612, 'pop': 71373, 'distance': 116.62304786346479}
# {'name': 'Vanderbijlpark', 'country': 'ZA', 'admin1': 'Gauteng', 'lat': -26.71171, 'lon': 27.83795, 'pop': 246754, 'distance': 110.0957094607097}
# {'name': 'Vereeniging', 'country': 'ZA', 'admin1': 'Gauteng', 'lat': -26.67313, 'lon': 27.92615, 'pop': 474681, 'distance': 110.00040790774642}
# {'name': 'Viljoenskroon', 'country': 'ZA', 'admin1': 'Free State', 'lat': -27.20841, 'lon': 26.94855, 'pop': 54955, 'distance': 111.11339254399985}
# {'name': 'Virginia', 'country': 'ZA', 'admin1': 'Free State', 'lat': -28.10391, 'lon': 26.86593, 'pop': 122502, 'distance': 111.65688854125301}
# {'name': 'Vryheid', 'country': 'ZA', 'admin1': 'Province of KwaZulu-Natal', 'lat': -27.76952, 'lon': 30.79165, 'pop': 150012, 'distance': 108.16849490732365}
# {'name': 'Warmbaths', 'country': 'ZA', 'admin1': 'Limpopo', 'lat': -24.88333, 'lon': 28.28333, 'pop': 90210, 'distance': 108.76287533609711}
# {'name': 'Welkom', 'country': 'ZA', 'admin1': 'Free State', 'lat': -27.97742, 'lon': 26.73506, 'pop': 431944, 'distance': 111.70068981492281}
# {'name': 'Wellington', 'country': 'ZA', 'admin1': 'Western Cape', 'lat': -33.63981, 'lon': 19.0112, 'pop': 55543, 'distance': 121.25362699556868}
# {'name': 'Westonaria', 'country': 'ZA', 'admin1': 'Gauteng', 'lat': -26.31905, 'lon': 27.6486, 'pop': 156831, 'distance': 110.05095428347953}
# {'name': 'Witbank', 'country': 'ZA', 'admin1': 'Mpumalanga', 'lat': -25.87133, 'lon': 29.23323, 'pop': 262491, 'distance': 108.46701212871774}
# {'name': 'Worcester', 'country': 'ZA', 'admin1': 'Western Cape', 'lat': -33.64651, 'lon': 19.44852, 'pop': 127597, 'distance': 120.88795797276295}
# {'name': 'Chililabombwe', 'country': 'ZM', 'admin1': 'Copperbelt Province', 'lat': -12.36475, 'lon': 27.82286, 'pop': 57328, 'distance': 103.28298326840148}
# {'name': 'Chingola', 'country': 'ZM', 'admin1': 'Copperbelt Province', 'lat': -12.52897, 'lon': 27.88382, 'pop': 148564, 'distance': 103.29716848972048}
# {'name': 'Chipata', 'country': 'ZM', 'admin1': 'Eastern Province', 'lat': -13.63333, 'lon': 32.65, 'pop': 85963, 'distance': 99.49317507631416}
# {'name': 'Kabwe', 'country': 'ZM', 'admin1': 'Central Province', 'lat': -14.4469, 'lon': 28.44644, 'pop': 188979, 'distance': 103.61867580990794}
# {'name': 'Kalulushi', 'country': 'ZM', 'admin1': 'Copperbelt Province', 'lat': -12.84151, 'lon': 28.09479, 'pop': 66575, 'distance': 103.23910347637565}
# {'name': 'Kasama', 'country': 'ZM', 'admin1': 'Northern Province', 'lat': -10.21289, 'lon': 31.18084, 'pop': 91056, 'distance': 99.3319927900397}
# {'name': 'Kitwe', 'country': 'ZM', 'admin1': 'Copperbelt Province', 'lat': -12.80243, 'lon': 28.21323, 'pop': 400914, 'distance': 103.11531471780224}
# {'name': 'Livingstone', 'country': 'ZM', 'admin1': 'Southern Province', 'lat': -17.84194, 'lon': 25.85425, 'pop': 109203, 'distance': 107.45873758341712}
# {'name': 'Luanshya', 'country': 'ZM', 'admin1': 'Copperbelt Province', 'lat': -13.13667, 'lon': 28.41661, 'pop': 113365, 'distance': 103.07483951059346}
# {'name': 'Lusaka', 'country': 'ZM', 'admin1': 'Lusaka Province', 'lat': -15.40669, 'lon': 28.28713, 'pop': 1267440, 'distance': 104.1877029445078}
# {'name': 'Mazabuka', 'country': 'ZM', 'admin1': 'Southern Province', 'lat': -15.85601, 'lon': 27.748, 'pop': 64006, 'distance': 104.87104025962792}
# {'name': 'Mongu', 'country': 'ZM', 'admin1': 'Western Province', 'lat': -15.24835, 'lon': 23.12741, 'pop': 52534, 'distance': 108.75858865187338}
# {'name': 'Mufulira', 'country': 'ZM', 'admin1': 'Copperbelt Province', 'lat': -12.54982, 'lon': 28.24071, 'pop': 120500, 'distance': 102.98284239029384}
# {'name': 'Ndola', 'country': 'ZM', 'admin1': 'Copperbelt Province', 'lat': -12.95867, 'lon': 28.63659, 'pop': 394518, 'distance': 102.7996903407447}
# {'name': 'Bulawayo', 'country': 'ZW', 'admin1': 'Bulawayo Province', 'lat': -20.15, 'lon': 28.58333, 'pop': 699385, 'distance': 106.13585850362402}
# {'name': 'Chinhoyi', 'country': 'ZW', 'admin1': 'Mashonaland West Province', 'lat': -17.36667, 'lon': 30.2, 'pop': 61739, 'distance': 103.38720301079674}
# {'name': 'Chitungwiza', 'country': 'ZW', 'admin1': 'Harare Province', 'lat': -18.01274, 'lon': 31.07555, 'pop': 340360, 'distance': 102.92268651809327}
# {'name': 'Gweru', 'country': 'ZW', 'admin1': 'Midlands Province', 'lat': -19.45, 'lon': 29.81667, 'pop': 146073, 'distance': 104.71780288403926}
# {'name': 'Harare', 'country': 'ZW', 'admin1': 'Harare Province', 'lat': -17.82772, 'lon': 31.05337, 'pop': 1542813, 'distance': 102.85380201042497}
# {'name': 'Kadoma', 'country': 'ZW', 'admin1': 'Mashonaland West Province', 'lat': -18.33328, 'lon': 29.91534, 'pop': 79174, 'distance': 104.09523123202331}
# {'name': 'Kwekwe', 'country': 'ZW', 'admin1': 'Midlands Province', 'lat': -18.92809, 'lon': 29.81486, 'pop': 99149, 'distance': 104.46784050288443}
# {'name': 'Marondera', 'country': 'ZW', 'admin1': 'Mashonaland East Province', 'lat': -18.18527, 'lon': 31.55193, 'pop': 57082, 'distance': 102.58758345763391}
# {'name': 'Masvingo', 'country': 'ZW', 'admin1': 'Masvingo Province', 'lat': -20.06373, 'lon': 30.82766, 'pop': 76290, 'distance': 104.13509529242532}
# {'name': 'Mutare', 'country': 'ZW', 'admin1': 'Manicaland Province', 'lat': -18.9707, 'lon': 32.67086, 'pop': 184205, 'distance': 101.99262768438905}
# {'name': 'Norton', 'country': 'ZW', 'admin1': 'Mashonaland West Province', 'lat': -17.88333, 'lon': 30.7, 'pop': 52054, 'distance': 103.19099038077937}

# %%
# Test 03D
Tests.test("03D", info_cities)
# Out:
# 03D: All tests passed 🎉🎉🎉

# %% [markdown]
# #### Exercise 03E:
#
# Now, sort the array from the previous step by distance and get the name and population of the $3$ cities closest to the largest city, but not including the largest city. In other words, if you sort the list from the exercise above by ascending `distance`, the $3$ cities closest to the largest city will be in the slice `[1:4]`. The city at index $0$ is the city with the largest population, and should have a distance of $0$ from itself.
#
# The answer should be an object where its keys are city names and values are populations.
#
# Something like:
#
# ```python
# closest_3 = {
#   "pittsburgh": 23412,
#   "liverpool": 172821,
#   "oakland": 182726
# }
# ```
#
# We saw how to sort lists of objects in lecture.

# %%
# Work on 03E here

# Sort the array and get the name and population of the 3 cities closest to the largest city

#step by step psuedo
#find the distance of each city to the largest city from the array


# then sort the array in ascending order



#do not include the laregst city in the dictionary



cities_by_distance = []

closest_3 = {}

# %%
# Test 03E
Tests.test("03E", closest_3)

# %% [markdown]
# ### Exercise 04:
#
# Visualizing data files.

# %% [markdown]
# #### Loading The Data:
#
# Let's load a JSON file that has information about houses in the Los Angeles metropolitan region of California.
#
# The file at this [url](https://raw.githubusercontent.com/PSAM-5020-2025S-A/5020-utils/main/datasets/json/LA_housing.json) has a list of objects formatted like this:
#
# ```python
# {
#   "longitude": -114.310,
#   "latitude": 34.190,
#   "age": 15,
#   "rooms": 12.234,
#   "bedrooms": 3.514,
#   "value": 669000
# }
# ```
#
# The number of rooms and bedrooms are not integers because some addresses have multiple units/apartments with different floorplans that get averaged.

# %%
# Define the location of the json file
HOUSES_FILE = "https://raw.githubusercontent.com/PSAM-5020-2026S-A/5020-utils/main/datasets/json/LA_housing.json"

# Use the object_from_json_url() function to load
# the json file into a Python object called "info_houses"

info_houses = object_from_json_url(HOUSES_FILE)

# %% [markdown]
# #### Exercise 04A:
#
# Explore the data and answer the following questions:
# - How many instances are there in our dataset?
# - What's the value of the most expensive house?
# - What's the max number of bedrooms in a house?
# - What's the number of bedrooms in the house with the most rooms?
# - What's the number of rooms in the house with the most bedrooms?

# %%
# Work on 04A here

# How many instances are there in our dataset?
# This is the same as asking "how many rows" or, in this case, "how many houses"

num_houses = 0


# What's the value of the most expensive house?

max_value = 0


# What's the number of bedrooms in the house with the most bedrooms?

most_bedrooms = 0


# What's the number of bedrooms in the house with the most rooms?

bedrooms_in_most_rooms = 0


# What's the number of rooms in the house with the most bedrooms?

rooms_in_most_bedrooms = 0

# %%
# Test 04A
answers = [num_houses, max_value, most_bedrooms, bedrooms_in_most_rooms, rooms_in_most_bedrooms]

Tests.test("04A", answers)

# %% [markdown]
# #### Exercise 04B:
#
# Which of the features (`longitude`, `latitude`, `age`, `rooms` or `bedrooms`) is a better indicator for value of a house?
#
# We're going to use XY scatter plots to visualize house value as a function of each of these features, and see if any of them show strong correlation.
#
# Documentation for the plotting library is here:
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html
#
# One thing to note is that the functions for plotting like to get lists of values and not lists of objects.
#
# Before we plot anything, let's define a function `list_from_key(objs, key)` that returns a list with all values of feature `key` for all of the objects in `objs`.

# %%
# Work on 04B here

# helper function to get lists of values from specific key
def list_from_key(objs, key):
  # TODO: implement the list_from_key functionality
  return []

# %%
# Test 04B
Tests.test("04B", list_from_key)

# %% [markdown]
# #### Exercise 04C:
#
# Now we can actually plot some values and start looking for correlations.
#
# Pick a feature and make a graph that shows house prices as a function of that feature.
#
# You can also write a for loop to plot graphs for all features.

# %%
# Work on 04C here

# TODO: get a list with all of the price values
prices = []

# TODO: get a list with all of the house ages (for example)
house_ages = []


# this is the command to plot a XY scatter plot from 2 lists
# see documentation: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html

plt.scatter(house_ages, prices)
plt.xlabel("age")
plt.ylabel("value")
plt.show()

# %% [markdown]
# #### What are some features that correlate with price ?

# %% [markdown]
# ### <span style="color:hotpink">Interpretation</span>
#
# <span style="color:hotpink">Answer 04C here. Double-click to edit Markdown.</span>

# %% [markdown]
# #### Foreshadowing:
#
# What if we use two features at a time?
#
# Is there a pair of features (`longitude`, `latitude`, `age`, `rooms` or `bedrooms`) that correlates to house value?
#
# We could look at the relationship between `price`, `age` and `rooms`:

# %%
# get a list with all of the price values
prices = list_from_key(info_houses, "value")

# get a list with all of the values of one feature
feature_0_values = list_from_key(info_houses, "age")

# get a list with all of the values of another feature
feature_1_values = list_from_key(info_houses, "rooms")

# this is how we plot an XY scatter plot using 3 lists
# see documentation: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html

plt.scatter(feature_0_values, feature_1_values, c=prices, alpha=0.3)
plt.xlabel("age")
plt.ylabel("rooms")
plt.show()

# %% [markdown]
# Or, we could write a little for loop to plot all possible pairs of features:

# %%
# to plot all feature pairs
# get list of all features
features = info_houses[0].keys()
prices = list_from_key(info_houses, "value")

# get all pairs of features
for idx_0, feature_0 in enumerate(features):
  x = list_from_key(info_houses, feature_0)
  for idx_1, feature_1 in enumerate(features):
    y = list_from_key(info_houses, feature_1)
    # skip repeated features
    if feature_0 != "value" and feature_1 != "value" and idx_1 > idx_0:
      plt.scatter(x, y, c=prices, alpha=0.3)
      plt.xlabel(feature_0)
      plt.ylabel(feature_1)
      plt.show()
